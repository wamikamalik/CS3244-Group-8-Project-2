# %% [markdown]
# # Extracting and Classifying Face Images
#
# https://dev.to/azure/opencv-detect-and-blur-faces-using-dnn-40ab
#
# https://towardsdatascience.com/face-detection-models-which-to-use-and-why-d263e82c302c

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, get_scorer_names, precision_score,recall_score,f1_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import seaborn as sns

# We import the data set from tensorflow and build the model there
import tensorflow as tf
from tensorflow.keras import layers, models
from keras.utils import np_utils
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Import the inception model  
from tensorflow.keras.applications.inception_v3 import InceptionV3
import shutil
from PIL import Image
from PIL import ImageFile

import torch
# If you do not have a GPU or do not want to run this code on your GPU, comment out the following lines
torch.cuda.empty_cache()
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Extracting the Data
#
# The images stored in the combined dataset are extracted into separate train and test set paths.
#
# NOTE: Before running this file, please unzip the Distacted Driver Dataset that contains the combined dataset.

# %%
PARENT_PATH = os.getcwd()
DATA_PATH = os.path.join(os.getcwd(), "Combined New")
TEST_PATH = os.path.join(DATA_PATH, "test")
TRAIN_PATH = os.path.join(DATA_PATH, "train")
UNSEEN_PATH = os.path.join(DATA_PATH, "unseen")
NUM_CLASSES = 8
TRAIN_PATH
# Out:
# 'c:\\Users\\wamik\\Documents\\Notes Y4S2\\CS3244\\Projects\\Project 2\\CS3244-Group-8-Project-2\\Combined New\\train'

# %%
CLASS = [["c0", "Safe Driving"], ["c1", "Text"], ["c2", "Phone"], 
         ["c3", "Adjusting Radio"], ["c4", "Drinking"], 
         ["c5", "Reaching Behind"], ["c6", "Hair or Makeup"], 
         ["c7", "Talking to Passenger"]]
TEST_CLS = [os.path.join(os.getcwd(), TEST_PATH, cls[0]) for cls in CLASS]
TRAIN_CLS = [os.path.join(os.getcwd(), TRAIN_PATH, cls[0]) for cls in CLASS]
for cls_path in TEST_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
for cls_path in TRAIN_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
# Out:
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c0
# 711
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c1
# 667
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c2
# 602
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c3
# 264
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c4
# 255
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c5
# 243
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c6
# 242
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c7
# 430
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c0
# 2131
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c1
# 2000
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c2
# 1805
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c3
# 791
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c4
# 762
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c5
# 726
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c6
# 723
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c7
# 1287

# %% [markdown]
# For each class, the path of the training and test data is stored in separate lists. The corresponding labels are also stored in a different list

# %%
train_paths = []
test_paths = []
for cls in range(NUM_CLASSES):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    train_paths.append(os.path.join(TRAIN_CLS[cls], train_instance))
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_paths.append(os.path.join(TEST_CLS[cls], test_instance))

# %%
classes = []
test_classes = []
for cls in range(NUM_CLASSES):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    classes.append(cls)
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_classes.append(cls)

# %% [markdown]
# Then separate dataframes storing the train and test paths with their corresponding labels are created.

# %%
df = pd.DataFrame({
  'filename': train_paths,
  'class': classes
})
df
# Out:
#                                                 filename  class
# 0      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                  ...    ...
# 10220  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10221  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10222  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10223  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10224  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [10225 rows x 2 columns]

# %%
df_test = pd.DataFrame({
  'filename': test_paths,
  'class': test_classes
})
df_test
# Out:
#                                                filename  class
# 0     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                 ...    ...
# 3409  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3410  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3411  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3412  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3413  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [3414 rows x 2 columns]

# %%
# -----------------------------------------------
# Face Detection using DNN Net
# -----------------------------------------------
# detect faces using a DNN model 
# download model and prototxt from https://github.com/spmallick/learnopencv/tree/master/FaceDetectionComparison/models

def detectFaceOpenCVDnn(net, frame):
    
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]
    blob = cv2.dnn.blobFromImage(frame, 1.0, mean = [104, 117, 123])

    net.setInput(blob)
    detections = net.forward()
    conf_threshold = 0.1
    box = None
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            conf_threshold = confidence
            x1 = int(detections[0, 0, i, 3] * frameWidth)
            y1 = int(detections[0, 0, i, 4] * frameHeight)
            x2 = int(detections[0, 0, i, 5] * frameWidth)
            y2 = int(detections[0, 0, i, 6] * frameHeight)
            box = [x1, y1, x2, y2]

    if box == None:
        return []
    # extract the face
    # face_boundary = frame[box[1]:box[3], box[0]:box[2]]

    return box

# %% [markdown]
# **NOTE: Before running the code below, please download and unzip the models folder in the same directory as this notebook. The models folder can be downloaded from here: https://github.com/spmallick/learnopencv/tree/master/FaceDetectionComparison/models**

# %%
# load face detection model
modelFile = "models/res10_300x300_ssd_iter_140000_fp16.caffemodel"
configFile = "models/deploy.prototxt"
net = cv2.dnn.readNetFromCaffe(configFile, modelFile)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

img_orig = cv2.imread(df['filename'].iloc[10000])
plt.imshow(img_orig)
plt.show()
frame = cv2.resize(img_orig, (640, 480))

extracted_face = detectFaceOpenCVDnn(net, frame)
face_boundary = frame[extracted_face[1]:extracted_face[3], extracted_face[0]:extracted_face[2]]
plt.imshow(face_boundary)
plt.show()

# %%
PARENT_PATH = os.getcwd()
DATA_PATH = os.path.join(os.getcwd(), "Combined New")
TEST_PATH = os.path.join(DATA_PATH, "test")
TRAIN_PATH = os.path.join(DATA_PATH, "train")
NEW_TRAIN_PATH = os.path.join(DATA_PATH, "new_train")
VALID_PATH = os.path.join(DATA_PATH, "valid")
UNSEEN_PATH = os.path.join(DATA_PATH, "unseen")
NUM_CLASSES = 8
CLS_LABELS = ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7']
SAVE_PATH = os.path.join(os.getcwd(), 'Combined new faces')

# %%
for class_folder in os.listdir(TRAIN_PATH):
  class_path = os.path.join(TRAIN_PATH, class_folder)
  if class_folder == ".DS_Store":
      continue
  train_imgs, test_imgs = train_test_split(os.listdir(class_path), test_size=0.2, random_state = 42)

  for img in train_imgs: 
    src = os.path.join(class_path, img)
    dst = os.path.join(NEW_TRAIN_PATH, class_folder, img)
    if not os.path.exists(os.path.join(NEW_TRAIN_PATH, class_folder)):
      os.makedirs(os.path.join(NEW_TRAIN_PATH, class_folder))
    shutil.copy(src, dst)

  for img in test_imgs: 
    src = os.path.join(class_path, img)
    dst = os.path.join(VALID_PATH, class_folder, img)
    if not os.path.exists(os.path.join(VALID_PATH, class_folder)):
      os.makedirs(os.path.join(VALID_PATH, class_folder))
    shutil.copy(src, dst)

# %%
datasets = [NEW_TRAIN_PATH, VALID_PATH, TEST_PATH, UNSEEN_PATH]
datasets_name = ['new_train', 'valid', 'test', 'unseen']

# %%
for dataset in datasets_name:
  for cls_label in CLS_LABELS:
    if not os.path.exists(os.path.join(SAVE_PATH, dataset, cls_label)):
       os.makedirs(os.path.join(SAVE_PATH, dataset, cls_label))

# %%
img_paths = []

for i in range(4):
  dataset = datasets[i]
  dataset_name = datasets_name[i]
  for cls_label in CLS_LABELS:
    cls_path = os.path.join(dataset, cls_label)
    for img in os.listdir(cls_path):
      if (img != '.DS_Store'):
        img_path = os.path.join(cls_path, img)
        img_orig = Image.open(img_path)
        img_re = img_orig.resize((640, 480))
        img_np = np.array(img_re)
        # Run object detection
        frame = detectFaceOpenCVDnn(net, img_np)
        width, height = img_re.size
        # Create a blank white image with the same dimensions as the original image
        # new_image = Image.new("RGB", (width, height), (255, 255, 255))
        box_pixels = img_re.crop((frame[0], frame[1], frame[2], frame[3]))
        pixels = np.array(box_pixels)
        pixels = cv2.cvtColor(pixels, cv2.COLOR_RGB2GRAY)
        final_img = Image.fromarray(pixels)
        save_path = os.path.join(SAVE_PATH, dataset_name, cls_label, img)
        if np.array(final_img).any():
          final_img.save(save_path)

# %% [markdown]
# ## Transfer Learning with TensorFlow Keras
#
# https://github.com/tejanirla/image_classification/blob/master/transfer_learning.ipynb

# %%
train_dir = "Combined new faces/new_train"
val_dir = "Combined new faces/valid"
test_dir = "Combined new faces/test"
# Add our data-augmentation parameters to ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255.,
                                   width_shift_range = 0.02,
                                   height_shift_range = 0.02,
                                   horizontal_flip = False)

# Note that the validation data should not be augmented!
val_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Note that the test data should not be augmented!
test_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Flow training images in batches of 40 using train_datagen generator
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size = 30,
                                                    class_mode = 'categorical', 
                                                    target_size = (100, 75), shuffle = True)   
# Flow validation images in batches of 40 using val_datagen generator
val_generator =  val_datagen.flow_from_directory( val_dir,
                                                          batch_size  = 30,
                                                          class_mode  = 'categorical', 
                                                          target_size = (100, 75), shuffle = True)  

# Flow validation images in batches of 40 using test_datagen generator
test_generator =  test_datagen.flow_from_directory( test_dir,
                                                          batch_size  = 30,
                                                          class_mode  = 'categorical', 
                                                          target_size = (100, 75), shuffle = False)
# Out:
# Found 7671 images belonging to 8 classes.
# Found 1913 images belonging to 8 classes.
# Found 3162 images belonging to 8 classes.

# %%
pre_trained_model = InceptionV3(input_shape = (100, 75, 3), # Shape of our images
                                include_top = False, # Leave out the last fully connected layer
                                weights = 'imagenet')
for layer in pre_trained_model.layers:
    layer.trainable = True

# %% [markdown]
# https://github.com/tejanirla/image_classification/blob/master/transfer_learning.ipynb

# %%
last_layer = pre_trained_model.get_layer('mixed4') #Only use layers including and above 'mixed4'
last_op = last_layer.output
# Flatten the output layer to 1 dimension
x = layers.Flatten()(last_op)
# # Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)                  
# Add a final sigmoid layer for classification
x = layers.Dense(8, activation='softmax')(x)           

model = keras.Model(pre_trained_model.input, x) 

model.compile(optimizer = keras.optimizers.SGD(learning_rate=0.001), 
              loss = 'categorical_crossentropy', 
              metrics = ['acc'])

# %%
from keras.callbacks import ModelCheckpoint


checkpoint = ModelCheckpoint(filepath='best_model_face_inception.h5', 
                             monitor="val_acc",
                             verbose=1, 
                             save_best_only=True, 
                             mode="max")
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor='val_acc', patience=10), checkpoint
]

history = model.fit(
            train_generator,
            validation_data = val_generator,
            steps_per_epoch = 160,
            epochs = 200,
            validation_steps = 60,
            verbose = 2,
            callbacks=callbacks_list)
# Out:
# Epoch 1/200
#
# Epoch 1: val_acc improved from -inf to 0.42611, saving model to best_model_face_inception.h5
# 160/160 - 23s - loss: 1.9681 - acc: 0.2819 - val_loss: 1.6443 - val_acc: 0.4261 - 23s/epoch - 142ms/step
# Epoch 2/200
#
# Epoch 2: val_acc improved from 0.42611 to 0.46889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.6469 - acc: 0.4101 - val_loss: 1.5304 - val_acc: 0.4689 - 20s/epoch - 124ms/step
# Epoch 3/200
#
# Epoch 3: val_acc improved from 0.46889 to 0.52889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.5302 - acc: 0.4525 - val_loss: 1.3885 - val_acc: 0.5289 - 20s/epoch - 125ms/step
# Epoch 4/200
#
# Epoch 4: val_acc improved from 0.52889 to 0.56833, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.4081 - acc: 0.5080 - val_loss: 1.2928 - val_acc: 0.5683 - 20s/epoch - 125ms/step
# Epoch 5/200
#
# Epoch 5: val_acc improved from 0.56833 to 0.59389, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.3271 - acc: 0.5308 - val_loss: 1.2415 - val_acc: 0.5939 - 20s/epoch - 127ms/step
# Epoch 6/200
#
# Epoch 6: val_acc improved from 0.59389 to 0.60889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.2642 - acc: 0.5558 - val_loss: 1.2017 - val_acc: 0.6089 - 20s/epoch - 127ms/step
# Epoch 7/200
#
# Epoch 7: val_acc improved from 0.60889 to 0.62889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.2265 - acc: 0.5792 - val_loss: 1.1527 - val_acc: 0.6289 - 20s/epoch - 126ms/step
# Epoch 8/200
#
# Epoch 8: val_acc did not improve from 0.62889
# 160/160 - 20s - loss: 1.1681 - acc: 0.5997 - val_loss: 1.1259 - val_acc: 0.6217 - 20s/epoch - 126ms/step
# Epoch 9/200
#
# Epoch 9: val_acc improved from 0.62889 to 0.65556, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.1258 - acc: 0.6147 - val_loss: 1.0703 - val_acc: 0.6556 - 20s/epoch - 126ms/step
# Epoch 10/200
#
# Epoch 10: val_acc improved from 0.65556 to 0.66722, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.0857 - acc: 0.6233 - val_loss: 1.0463 - val_acc: 0.6672 - 20s/epoch - 127ms/step
# Epoch 11/200
#
# Epoch 11: val_acc improved from 0.66722 to 0.66889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.0425 - acc: 0.6481 - val_loss: 1.0311 - val_acc: 0.6689 - 20s/epoch - 126ms/step
# Epoch 12/200
#
# Epoch 12: val_acc improved from 0.66889 to 0.68222, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.0123 - acc: 0.6589 - val_loss: 0.9828 - val_acc: 0.6822 - 20s/epoch - 127ms/step
# Epoch 13/200
#
# Epoch 13: val_acc improved from 0.68222 to 0.68500, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 1.0069 - acc: 0.6581 - val_loss: 0.9814 - val_acc: 0.6850 - 20s/epoch - 127ms/step
# Epoch 14/200
#
# Epoch 14: val_acc improved from 0.68500 to 0.69944, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.9595 - acc: 0.6748 - val_loss: 0.9528 - val_acc: 0.6994 - 20s/epoch - 126ms/step
# Epoch 15/200
#
# Epoch 15: val_acc did not improve from 0.69944
# 160/160 - 20s - loss: 0.9142 - acc: 0.6890 - val_loss: 0.9293 - val_acc: 0.6967 - 20s/epoch - 125ms/step
# Epoch 16/200
#
# Epoch 16: val_acc improved from 0.69944 to 0.70500, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.8990 - acc: 0.7013 - val_loss: 0.9184 - val_acc: 0.7050 - 20s/epoch - 127ms/step
# Epoch 17/200
#
# Epoch 17: val_acc improved from 0.70500 to 0.70556, saving model to best_model_face_inception.h5
# 160/160 - 21s - loss: 0.8604 - acc: 0.7120 - val_loss: 0.8980 - val_acc: 0.7056 - 21s/epoch - 132ms/step
# Epoch 18/200
#
# Epoch 18: val_acc improved from 0.70556 to 0.71278, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.8390 - acc: 0.7227 - val_loss: 0.8846 - val_acc: 0.7128 - 20s/epoch - 126ms/step
# Epoch 19/200
#
# Epoch 19: val_acc improved from 0.71278 to 0.72889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.8078 - acc: 0.7387 - val_loss: 0.8450 - val_acc: 0.7289 - 20s/epoch - 126ms/step
# Epoch 20/200
#
# Epoch 20: val_acc improved from 0.72889 to 0.73389, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.8025 - acc: 0.7385 - val_loss: 0.8479 - val_acc: 0.7339 - 20s/epoch - 126ms/step
# Epoch 21/200
#
# Epoch 21: val_acc did not improve from 0.73389
# 160/160 - 20s - loss: 0.7777 - acc: 0.7474 - val_loss: 0.8185 - val_acc: 0.7339 - 20s/epoch - 125ms/step
# Epoch 22/200
#
# Epoch 22: val_acc did not improve from 0.73389
# 160/160 - 20s - loss: 0.7476 - acc: 0.7581 - val_loss: 0.8346 - val_acc: 0.7267 - 20s/epoch - 124ms/step
# Epoch 23/200
#
# Epoch 23: val_acc did not improve from 0.73389
# 160/160 - 20s - loss: 0.7422 - acc: 0.7575 - val_loss: 0.8158 - val_acc: 0.7339 - 20s/epoch - 124ms/step
# Epoch 24/200
#
# Epoch 24: val_acc improved from 0.73389 to 0.74056, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.7257 - acc: 0.7639 - val_loss: 0.7934 - val_acc: 0.7406 - 20s/epoch - 126ms/step
# Epoch 25/200
#
# Epoch 25: val_acc improved from 0.74056 to 0.74111, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.6994 - acc: 0.7769 - val_loss: 0.7732 - val_acc: 0.7411 - 20s/epoch - 126ms/step
# Epoch 26/200
#
# Epoch 26: val_acc improved from 0.74111 to 0.74944, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.6855 - acc: 0.7796 - val_loss: 0.7719 - val_acc: 0.7494 - 20s/epoch - 125ms/step
# Epoch 27/200
#
# Epoch 27: val_acc improved from 0.74944 to 0.75556, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.6827 - acc: 0.7808 - val_loss: 0.7509 - val_acc: 0.7556 - 20s/epoch - 126ms/step
# Epoch 28/200
#
# Epoch 28: val_acc did not improve from 0.75556
# 160/160 - 20s - loss: 0.6504 - acc: 0.7952 - val_loss: 0.7608 - val_acc: 0.7544 - 20s/epoch - 124ms/step
# Epoch 29/200
#
# Epoch 29: val_acc improved from 0.75556 to 0.75611, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.6381 - acc: 0.7909 - val_loss: 0.7513 - val_acc: 0.7561 - 20s/epoch - 126ms/step
# Epoch 30/200
#
# Epoch 30: val_acc improved from 0.75611 to 0.76222, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.6347 - acc: 0.7992 - val_loss: 0.7260 - val_acc: 0.7622 - 20s/epoch - 126ms/step
# Epoch 31/200
#
# Epoch 31: val_acc did not improve from 0.76222
# 160/160 - 20s - loss: 0.6091 - acc: 0.8046 - val_loss: 0.7323 - val_acc: 0.7583 - 20s/epoch - 124ms/step
# Epoch 32/200
#
# Epoch 32: val_acc did not improve from 0.76222
# 160/160 - 20s - loss: 0.6006 - acc: 0.8061 - val_loss: 0.7300 - val_acc: 0.7594 - 20s/epoch - 124ms/step
# Epoch 33/200
#
# Epoch 33: val_acc improved from 0.76222 to 0.76667, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.5767 - acc: 0.8192 - val_loss: 0.6989 - val_acc: 0.7667 - 20s/epoch - 126ms/step
# Epoch 34/200
#
# Epoch 34: val_acc did not improve from 0.76667
# 160/160 - 20s - loss: 0.5852 - acc: 0.8104 - val_loss: 0.7173 - val_acc: 0.7661 - 20s/epoch - 124ms/step
# Epoch 35/200
#
# Epoch 35: val_acc improved from 0.76667 to 0.76944, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.5637 - acc: 0.8175 - val_loss: 0.6901 - val_acc: 0.7694 - 20s/epoch - 126ms/step
# Epoch 36/200
#
# Epoch 36: val_acc improved from 0.76944 to 0.77222, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.5408 - acc: 0.8269 - val_loss: 0.7015 - val_acc: 0.7722 - 20s/epoch - 127ms/step
# Epoch 37/200
#
# Epoch 37: val_acc did not improve from 0.77222
# 160/160 - 20s - loss: 0.5261 - acc: 0.8414 - val_loss: 0.6991 - val_acc: 0.7650 - 20s/epoch - 125ms/step
# Epoch 38/200
#
# Epoch 38: val_acc improved from 0.77222 to 0.77500, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.5061 - acc: 0.8412 - val_loss: 0.6806 - val_acc: 0.7750 - 20s/epoch - 127ms/step
# Epoch 39/200
#
# Epoch 39: val_acc improved from 0.77500 to 0.77778, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.5176 - acc: 0.8347 - val_loss: 0.6821 - val_acc: 0.7778 - 20s/epoch - 128ms/step
# Epoch 40/200
#
# Epoch 40: val_acc improved from 0.77778 to 0.77889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.4935 - acc: 0.8473 - val_loss: 0.6683 - val_acc: 0.7789 - 20s/epoch - 127ms/step
# Epoch 41/200
#
# Epoch 41: val_acc did not improve from 0.77889
# 160/160 - 20s - loss: 0.4951 - acc: 0.8410 - val_loss: 0.6685 - val_acc: 0.7778 - 20s/epoch - 126ms/step
# Epoch 42/200
#
# Epoch 42: val_acc did not improve from 0.77889
# 160/160 - 20s - loss: 0.4870 - acc: 0.8404 - val_loss: 0.6594 - val_acc: 0.7778 - 20s/epoch - 125ms/step
# Epoch 43/200
#
# Epoch 43: val_acc improved from 0.77889 to 0.78667, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.4896 - acc: 0.8460 - val_loss: 0.6506 - val_acc: 0.7867 - 20s/epoch - 128ms/step
# Epoch 44/200
#
# Epoch 44: val_acc did not improve from 0.78667
# 160/160 - 20s - loss: 0.4644 - acc: 0.8528 - val_loss: 0.6580 - val_acc: 0.7772 - 20s/epoch - 126ms/step
# Epoch 45/200
#
# Epoch 45: val_acc improved from 0.78667 to 0.78944, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.4629 - acc: 0.8545 - val_loss: 0.6442 - val_acc: 0.7894 - 20s/epoch - 127ms/step
# Epoch 46/200
#
# Epoch 46: val_acc improved from 0.78944 to 0.79778, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.4427 - acc: 0.8547 - val_loss: 0.6386 - val_acc: 0.7978 - 20s/epoch - 128ms/step
# Epoch 47/200
#
# Epoch 47: val_acc did not improve from 0.79778
# 160/160 - 20s - loss: 0.4487 - acc: 0.8602 - val_loss: 0.6365 - val_acc: 0.7961 - 20s/epoch - 126ms/step
# Epoch 48/200
#
# Epoch 48: val_acc did not improve from 0.79778
# 160/160 - 20s - loss: 0.4308 - acc: 0.8673 - val_loss: 0.6350 - val_acc: 0.7867 - 20s/epoch - 127ms/step
# Epoch 49/200
#
# Epoch 49: val_acc did not improve from 0.79778
# 160/160 - 20s - loss: 0.4122 - acc: 0.8721 - val_loss: 0.6360 - val_acc: 0.7939 - 20s/epoch - 126ms/step
# Epoch 50/200
#
# Epoch 50: val_acc did not improve from 0.79778
# 160/160 - 20s - loss: 0.4124 - acc: 0.8723 - val_loss: 0.6154 - val_acc: 0.7972 - 20s/epoch - 127ms/step
# Epoch 51/200
#
# Epoch 51: val_acc improved from 0.79778 to 0.80500, saving model to best_model_face_inception.h5
# 160/160 - 21s - loss: 0.3940 - acc: 0.8766 - val_loss: 0.6301 - val_acc: 0.8050 - 21s/epoch - 128ms/step
# Epoch 52/200
#
# Epoch 52: val_acc did not improve from 0.80500
# 160/160 - 20s - loss: 0.4006 - acc: 0.8813 - val_loss: 0.6262 - val_acc: 0.7961 - 20s/epoch - 127ms/step
# Epoch 53/200
#
# Epoch 53: val_acc improved from 0.80500 to 0.81111, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.3742 - acc: 0.8865 - val_loss: 0.6002 - val_acc: 0.8111 - 20s/epoch - 128ms/step
# Epoch 54/200
#
# Epoch 54: val_acc did not improve from 0.81111
# 160/160 - 20s - loss: 0.3748 - acc: 0.8881 - val_loss: 0.6242 - val_acc: 0.8072 - 20s/epoch - 127ms/step
# Epoch 55/200
#
# Epoch 55: val_acc did not improve from 0.81111
# 160/160 - 20s - loss: 0.3732 - acc: 0.8833 - val_loss: 0.6084 - val_acc: 0.8072 - 20s/epoch - 127ms/step
# Epoch 56/200
#
# Epoch 56: val_acc improved from 0.81111 to 0.81278, saving model to best_model_face_inception.h5
# 160/160 - 21s - loss: 0.3746 - acc: 0.8794 - val_loss: 0.5937 - val_acc: 0.8128 - 21s/epoch - 129ms/step
# Epoch 57/200
#
# Epoch 57: val_acc did not improve from 0.81278
# 160/160 - 20s - loss: 0.3559 - acc: 0.8940 - val_loss: 0.6113 - val_acc: 0.8083 - 20s/epoch - 126ms/step
# Epoch 58/200
#
# Epoch 58: val_acc did not improve from 0.81278
# 160/160 - 20s - loss: 0.3614 - acc: 0.8910 - val_loss: 0.5956 - val_acc: 0.8083 - 20s/epoch - 127ms/step
# Epoch 59/200
#
# Epoch 59: val_acc did not improve from 0.81278
# 160/160 - 20s - loss: 0.3413 - acc: 0.8973 - val_loss: 0.6024 - val_acc: 0.8078 - 20s/epoch - 126ms/step
# Epoch 60/200
#
# Epoch 60: val_acc did not improve from 0.81278
# 160/160 - 20s - loss: 0.3412 - acc: 0.8929 - val_loss: 0.6012 - val_acc: 0.8083 - 20s/epoch - 127ms/step
# Epoch 61/200
#
# Epoch 61: val_acc improved from 0.81278 to 0.81833, saving model to best_model_face_inception.h5
# 160/160 - 21s - loss: 0.3276 - acc: 0.9021 - val_loss: 0.5833 - val_acc: 0.8183 - 21s/epoch - 130ms/step
# Epoch 62/200
#
# Epoch 62: val_acc did not improve from 0.81833
# 160/160 - 20s - loss: 0.3353 - acc: 0.8994 - val_loss: 0.5797 - val_acc: 0.8178 - 20s/epoch - 126ms/step
# Epoch 63/200
#
# Epoch 63: val_acc improved from 0.81833 to 0.81889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.3164 - acc: 0.9038 - val_loss: 0.5866 - val_acc: 0.8189 - 20s/epoch - 128ms/step
# Epoch 64/200
#
# Epoch 64: val_acc did not improve from 0.81889
# 160/160 - 20s - loss: 0.3169 - acc: 0.9073 - val_loss: 0.5837 - val_acc: 0.8139 - 20s/epoch - 126ms/step
# Epoch 65/200
#
# Epoch 65: val_acc did not improve from 0.81889
# 160/160 - 20s - loss: 0.3108 - acc: 0.9063 - val_loss: 0.5866 - val_acc: 0.8172 - 20s/epoch - 126ms/step
# Epoch 66/200
#
# Epoch 66: val_acc improved from 0.81889 to 0.81944, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.3034 - acc: 0.9084 - val_loss: 0.5838 - val_acc: 0.8194 - 20s/epoch - 128ms/step
# Epoch 67/200
#
# Epoch 67: val_acc did not improve from 0.81944
# 160/160 - 20s - loss: 0.3024 - acc: 0.9065 - val_loss: 0.5851 - val_acc: 0.8189 - 20s/epoch - 126ms/step
# Epoch 68/200
#
# Epoch 68: val_acc improved from 0.81944 to 0.82333, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2964 - acc: 0.9088 - val_loss: 0.5770 - val_acc: 0.8233 - 20s/epoch - 127ms/step
# Epoch 69/200
#
# Epoch 69: val_acc improved from 0.82333 to 0.82389, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2918 - acc: 0.9105 - val_loss: 0.5748 - val_acc: 0.8239 - 20s/epoch - 128ms/step
# Epoch 70/200
#
# Epoch 70: val_acc did not improve from 0.82389
# 160/160 - 20s - loss: 0.2851 - acc: 0.9140 - val_loss: 0.5870 - val_acc: 0.8189 - 20s/epoch - 126ms/step
# Epoch 71/200
#
# Epoch 71: val_acc improved from 0.82389 to 0.82500, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2777 - acc: 0.9202 - val_loss: 0.5697 - val_acc: 0.8250 - 20s/epoch - 127ms/step
# Epoch 72/200
#
# Epoch 72: val_acc improved from 0.82500 to 0.82722, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2754 - acc: 0.9176 - val_loss: 0.5577 - val_acc: 0.8272 - 20s/epoch - 127ms/step
# Epoch 73/200
#
# Epoch 73: val_acc did not improve from 0.82722
# 160/160 - 20s - loss: 0.2696 - acc: 0.9198 - val_loss: 0.5599 - val_acc: 0.8222 - 20s/epoch - 126ms/step
# Epoch 74/200
#
# Epoch 74: val_acc did not improve from 0.82722
# 160/160 - 20s - loss: 0.2719 - acc: 0.9148 - val_loss: 0.5701 - val_acc: 0.8261 - 20s/epoch - 125ms/step
# Epoch 75/200
#
# Epoch 75: val_acc did not improve from 0.82722
# 160/160 - 20s - loss: 0.2539 - acc: 0.9256 - val_loss: 0.5771 - val_acc: 0.8233 - 20s/epoch - 126ms/step
# Epoch 76/200
#
# Epoch 76: val_acc did not improve from 0.82722
# 160/160 - 20s - loss: 0.2580 - acc: 0.9210 - val_loss: 0.5784 - val_acc: 0.8206 - 20s/epoch - 124ms/step
# Epoch 77/200
#
# Epoch 77: val_acc improved from 0.82722 to 0.82889, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2585 - acc: 0.9255 - val_loss: 0.5646 - val_acc: 0.8289 - 20s/epoch - 127ms/step
# Epoch 78/200
#
# Epoch 78: val_acc did not improve from 0.82889
# 160/160 - 20s - loss: 0.2453 - acc: 0.9281 - val_loss: 0.5585 - val_acc: 0.8278 - 20s/epoch - 125ms/step
# Epoch 79/200
#
# Epoch 79: val_acc improved from 0.82889 to 0.83222, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2325 - acc: 0.9307 - val_loss: 0.5603 - val_acc: 0.8322 - 20s/epoch - 127ms/step
# Epoch 80/200
#
# Epoch 80: val_acc did not improve from 0.83222
# 160/160 - 20s - loss: 0.2512 - acc: 0.9226 - val_loss: 0.5635 - val_acc: 0.8283 - 20s/epoch - 124ms/step
# Epoch 81/200
#
# Epoch 81: val_acc did not improve from 0.83222
# 160/160 - 20s - loss: 0.2487 - acc: 0.9232 - val_loss: 0.5658 - val_acc: 0.8289 - 20s/epoch - 125ms/step
# Epoch 82/200
#
# Epoch 82: val_acc did not improve from 0.83222
# 160/160 - 20s - loss: 0.2384 - acc: 0.9267 - val_loss: 0.5686 - val_acc: 0.8244 - 20s/epoch - 125ms/step
# Epoch 83/200
#
# Epoch 83: val_acc did not improve from 0.83222
# 160/160 - 20s - loss: 0.2315 - acc: 0.9317 - val_loss: 0.5670 - val_acc: 0.8322 - 20s/epoch - 125ms/step
# Epoch 84/200
#
# Epoch 84: val_acc did not improve from 0.83222
# 160/160 - 20s - loss: 0.2267 - acc: 0.9332 - val_loss: 0.5451 - val_acc: 0.8317 - 20s/epoch - 125ms/step
# Epoch 85/200
#
# Epoch 85: val_acc improved from 0.83222 to 0.83556, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2145 - acc: 0.9393 - val_loss: 0.5583 - val_acc: 0.8356 - 20s/epoch - 127ms/step
# Epoch 86/200
#
# Epoch 86: val_acc improved from 0.83556 to 0.83722, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2118 - acc: 0.9406 - val_loss: 0.5547 - val_acc: 0.8372 - 20s/epoch - 126ms/step
# Epoch 87/200
#
# Epoch 87: val_acc did not improve from 0.83722
# 160/160 - 20s - loss: 0.2135 - acc: 0.9392 - val_loss: 0.5452 - val_acc: 0.8361 - 20s/epoch - 125ms/step
# Epoch 88/200
#
# Epoch 88: val_acc did not improve from 0.83722
# 160/160 - 20s - loss: 0.2007 - acc: 0.9465 - val_loss: 0.5576 - val_acc: 0.8317 - 20s/epoch - 126ms/step
# Epoch 89/200
#
# Epoch 89: val_acc did not improve from 0.83722
# 160/160 - 20s - loss: 0.2073 - acc: 0.9424 - val_loss: 0.5680 - val_acc: 0.8328 - 20s/epoch - 125ms/step
# Epoch 90/200
#
# Epoch 90: val_acc did not improve from 0.83722
# 160/160 - 20s - loss: 0.2060 - acc: 0.9432 - val_loss: 0.5571 - val_acc: 0.8361 - 20s/epoch - 125ms/step
# Epoch 91/200
#
# Epoch 91: val_acc improved from 0.83722 to 0.83944, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.2012 - acc: 0.9431 - val_loss: 0.5507 - val_acc: 0.8394 - 20s/epoch - 127ms/step
# Epoch 92/200
#
# Epoch 92: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1955 - acc: 0.9468 - val_loss: 0.5674 - val_acc: 0.8306 - 20s/epoch - 125ms/step
# Epoch 93/200
#
# Epoch 93: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1978 - acc: 0.9430 - val_loss: 0.5504 - val_acc: 0.8372 - 20s/epoch - 124ms/step
# Epoch 94/200
#
# Epoch 94: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1912 - acc: 0.9443 - val_loss: 0.5509 - val_acc: 0.8344 - 20s/epoch - 125ms/step
# Epoch 95/200
#
# Epoch 95: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1868 - acc: 0.9499 - val_loss: 0.5409 - val_acc: 0.8367 - 20s/epoch - 124ms/step
# Epoch 96/200
#
# Epoch 96: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1852 - acc: 0.9476 - val_loss: 0.5573 - val_acc: 0.8328 - 20s/epoch - 125ms/step
# Epoch 97/200
#
# Epoch 97: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1858 - acc: 0.9505 - val_loss: 0.5513 - val_acc: 0.8389 - 20s/epoch - 126ms/step
# Epoch 98/200
#
# Epoch 98: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1812 - acc: 0.9512 - val_loss: 0.5536 - val_acc: 0.8394 - 20s/epoch - 125ms/step
# Epoch 99/200
#
# Epoch 99: val_acc did not improve from 0.83944
# 160/160 - 20s - loss: 0.1796 - acc: 0.9476 - val_loss: 0.5517 - val_acc: 0.8367 - 20s/epoch - 128ms/step
# Epoch 100/200
#
# Epoch 100: val_acc improved from 0.83944 to 0.84500, saving model to best_model_face_inception.h5
# 160/160 - 21s - loss: 0.1796 - acc: 0.9483 - val_loss: 0.5433 - val_acc: 0.8450 - 21s/epoch - 130ms/step
# Epoch 101/200
#
# Epoch 101: val_acc did not improve from 0.84500
# 160/160 - 20s - loss: 0.1753 - acc: 0.9482 - val_loss: 0.5495 - val_acc: 0.8406 - 20s/epoch - 124ms/step
# Epoch 102/200
#
# Epoch 102: val_acc did not improve from 0.84500
# 160/160 - 20s - loss: 0.1778 - acc: 0.9468 - val_loss: 0.5455 - val_acc: 0.8383 - 20s/epoch - 126ms/step
# Epoch 103/200
#
# Epoch 103: val_acc did not improve from 0.84500
# 160/160 - 20s - loss: 0.1663 - acc: 0.9540 - val_loss: 0.5525 - val_acc: 0.8389 - 20s/epoch - 125ms/step
# Epoch 104/200
#
# Epoch 104: val_acc did not improve from 0.84500
# 160/160 - 20s - loss: 0.1667 - acc: 0.9512 - val_loss: 0.5472 - val_acc: 0.8383 - 20s/epoch - 125ms/step
# Epoch 105/200
#
# Epoch 105: val_acc improved from 0.84500 to 0.84778, saving model to best_model_face_inception.h5
# 160/160 - 20s - loss: 0.1681 - acc: 0.9529 - val_loss: 0.5402 - val_acc: 0.8478 - 20s/epoch - 126ms/step
# Epoch 106/200
#
# Epoch 106: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1638 - acc: 0.9526 - val_loss: 0.5523 - val_acc: 0.8422 - 20s/epoch - 125ms/step
# Epoch 107/200
#
# Epoch 107: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1613 - acc: 0.9532 - val_loss: 0.5355 - val_acc: 0.8444 - 20s/epoch - 125ms/step
# Epoch 108/200
#
# Epoch 108: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1588 - acc: 0.9535 - val_loss: 0.5473 - val_acc: 0.8433 - 20s/epoch - 125ms/step
# Epoch 109/200
#
# Epoch 109: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1571 - acc: 0.9540 - val_loss: 0.5474 - val_acc: 0.8411 - 20s/epoch - 125ms/step
# Epoch 110/200
#
# Epoch 110: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1498 - acc: 0.9600 - val_loss: 0.5565 - val_acc: 0.8406 - 20s/epoch - 125ms/step
# Epoch 111/200
#
# Epoch 111: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1507 - acc: 0.9572 - val_loss: 0.5460 - val_acc: 0.8389 - 20s/epoch - 126ms/step
# Epoch 112/200
#
# Epoch 112: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1481 - acc: 0.9610 - val_loss: 0.5502 - val_acc: 0.8394 - 20s/epoch - 125ms/step
# Epoch 113/200
#
# Epoch 113: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1465 - acc: 0.9610 - val_loss: 0.5468 - val_acc: 0.8428 - 20s/epoch - 125ms/step
# Epoch 114/200
#
# Epoch 114: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1385 - acc: 0.9658 - val_loss: 0.5518 - val_acc: 0.8400 - 20s/epoch - 125ms/step
# Epoch 115/200
#
# Epoch 115: val_acc did not improve from 0.84778
# 160/160 - 20s - loss: 0.1380 - acc: 0.9624 - val_loss: 0.5566 - val_acc: 0.8428 - 20s/epoch - 125ms/step

# %%
# summarize history for accuracy and loss
plt.figure(figsize=(6, 4))
plt.plot(history.history['acc'], "g--", label="Accuracy of training data")
plt.plot(history.history['val_acc'], "g", label="Accuracy of validation data")
plt.plot(history.history['loss'], "r--", label="Loss of training data")
plt.plot(history.history['val_loss'], "r", label="Loss of validation data")
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# %%
model = keras.models.load_model("best_model_face_inception.h5")
score = model.evaluate(test_generator, verbose=1)
print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 106/106 [==============================] - 4s 31ms/step - loss: 0.4810 - acc: 0.8555
#
# Accuracy on test data: 0.86
#
# Loss on test data: 0.48

# %%
y_pred_test = model.predict(test_generator)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = test_generator.classes
precision = precision_score(max_y_test, max_y_pred_test, average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(max_y_test, max_y_pred_test, average='weighted')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(max_y_test, max_y_pred_test, average='weighted')
print('F1 score: %f' % f1)
# Out:
# 106/106 [==============================] - 4s 30ms/step
# Precision: 0.855615
# Recall: 0.855471
# F1 score: 0.854926

# %%
LABELS = [0, 1, 2, 3, 4, 5, 6, 7]
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap="coolwarm",
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.show()

# %%
show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86       657
#            1       0.85      0.90      0.88       631
#            2       0.85      0.86      0.85       542
#            3       0.88      0.84      0.86       258
#            4       0.81      0.73      0.77       221
#            5       0.84      0.73      0.78       216
#            6       0.72      0.75      0.74       207
#            7       0.97      0.95      0.96       430
#
#     accuracy                           0.86      3162
#    macro avg       0.84      0.83      0.84      3162
# weighted avg       0.86      0.86      0.85      3162

# %% [markdown]
# ## Testing Results on Unseen Drivers
#
# ### Preparing Unseen Drivers Data
#
# We will now evaluate model performance on drivers it hasn't seen before. First, we prepare the data for evaluation.

# %%
unseen_dir = "Combined new faces/unseen"
# Note that the test data should not be augmented!
unseen_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Flow training images in batches of 40 using train_datagen generator
unseen_generator = unseen_datagen.flow_from_directory(unseen_dir,
                                                    batch_size = 30,
                                                    class_mode = 'categorical', 
                                                    target_size = (100, 75), shuffle = False)
# Out:
# Found 653 images belonging to 8 classes.

# %%
model_inception = keras.models.load_model('best_model_face_inception.h5')
score = model_inception.evaluate(unseen_generator, verbose=1)

print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 22/22 [==============================] - 2s 34ms/step - loss: 2.3121 - acc: 0.3660
#
# Accuracy on test data: 0.37
#
# Loss on test data: 2.31

# %%
y_pred_test = model_inception.predict(unseen_generator)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = unseen_generator.classes

show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 22/22 [==============================] - 1s 38ms/step
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.31      0.41      0.35        87
#            1       0.17      0.04      0.07       137
#            2       0.32      0.25      0.28       117
#            3       0.20      0.44      0.28        61
#            4       0.45      0.23      0.31        39
#            5       0.47      0.45      0.46        64
#            6       0.28      0.43      0.34        68
#            7       0.84      0.93      0.88        80
#
#     accuracy                           0.37       653
#    macro avg       0.38      0.40      0.37       653
# weighted avg       0.36      0.37      0.34       653
