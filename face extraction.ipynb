# %% [markdown]
# # Extracting and Classifying Face Images
#
# https://dev.to/azure/opencv-detect-and-blur-faces-using-dnn-40ab
#
# https://towardsdatascience.com/face-detection-models-which-to-use-and-why-d263e82c302c

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import image
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, get_scorer_names
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from mtcnn.mtcnn import MTCNN
from PIL import Image
from sklearn import metrics
import seaborn as sns

# We import the data set from tensorflow and build the model there
import tensorflow as tf
from tensorflow.keras import layers, models
from keras.utils import np_utils
import keras
import torch
# If you do not have a GPU or do not want to run this code on your GPU, comment out the following lines
torch.cuda.empty_cache()
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Extracting the Data
#
# The images stored in the combined dataset are extracted into separate train and test set paths.
#
# NOTE: Before running this file, please unzip the Distacted Driver Dataset that contains the combined dataset.

# %%
CLASS = [["c0", "Safe Driving"], ["c1", "Text"], ["c2", "Phone"], 
         ["c3", "Adjusting Radio"], ["c4", "Drinking"], 
         ["c5", "Reaching Behind"], ["c6", "Hair or Makeup"], 
         ["c7", "Talking to Passenger"]]
TEST_CLS = [os.path.join(os.getcwd(), "Distracted Driver Dataset", "Combined", "test", cls[0]) for cls in CLASS]
TRAIN_CLS = [os.path.join(os.getcwd(), "Distracted Driver Dataset", "Combined", "train", cls[0]) for cls in CLASS]
for cls_path in TEST_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
for cls_path in TRAIN_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
# Out:
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c0
# 346
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c1
# 393
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c2
# 364
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c3
# 170
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c4
# 143
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c5
# 143
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c6
# 146
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\test\c7
# 218
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c0
# 2640
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c1
# 2449
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c2
# 2212
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c3
# 953
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c4
# 933
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c5
# 891
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c6
# 898
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Distracted Driver Dataset\Combined\train\c7
# 1579

# %% [markdown]
# For each class, the path of the training and test data is stored in separate lists. The corresponding labels are also stored in a different list

# %%
train_paths = []
test_paths = []
for cls in range(8):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    train_paths.append(os.path.join(TRAIN_CLS[cls], train_instance))
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_paths.append(os.path.join(TEST_CLS[cls], test_instance))

# %%
classes = []
test_classes = []
for cls in range(8):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    classes.append(cls)
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_classes.append(cls)

# %% [markdown]
# Then separate dataframes storing the train and test paths with their corresponding labels are created.

# %%
df = pd.DataFrame({
  'filename': train_paths,
  'class': classes
})
df
# Out:
#                                                 filename  class
# 0      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                  ...    ...
# 12550  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 12551  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 12552  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 12553  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 12554  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [12555 rows x 2 columns]

# %%
df_test = pd.DataFrame({
  'filename': test_paths,
  'class': test_classes
})
df_test
# Out:
#                                                filename  class
# 0     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                 ...    ...
# 1918  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 1919  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 1920  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 1921  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 1922  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [1923 rows x 2 columns]

# %%
# -----------------------------------------------
# Face Detection using DNN Net
# -----------------------------------------------
# detect faces using a DNN model 
# download model and prototxt from https://github.com/spmallick/learnopencv/tree/master/FaceDetectionComparison/models

def detectFaceOpenCVDnn(net, frame):
    
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]
    blob = cv2.dnn.blobFromImage(frame, 1.0, mean = [104, 117, 123])

    net.setInput(blob)
    detections = net.forward()
    conf_threshold = 0.1
    box = None
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            conf_threshold = confidence
            x1 = int(detections[0, 0, i, 3] * frameWidth)
            y1 = int(detections[0, 0, i, 4] * frameHeight)
            x2 = int(detections[0, 0, i, 5] * frameWidth)
            y2 = int(detections[0, 0, i, 6] * frameHeight)
            box = [x1, y1, x2, y2]

    if box == None:
        return []
    # extract the face
    face_boundary = frame[box[1]:box[3], box[0]:box[2]]

    # resize pixels to the model size
    # face_image = Image.fromarray(face_boundary)
    # face_array = np.asarray(face_image)

    return face_boundary

# %%
# load face detection model
modelFile = "models/res10_300x300_ssd_iter_140000_fp16.caffemodel"
configFile = "models/deploy.prototxt"
net = cv2.dnn.readNetFromCaffe(configFile, modelFile)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

img_orig = cv2.imread(df['filename'].iloc[10000])
plt.imshow(img_orig)
plt.show()
frame = cv2.resize(img_orig, (640, 480))

extracted_face = detectFaceOpenCVDnn(net, frame)
plt.imshow(extracted_face)
plt.show()

# %%
X_train_final = []
Y_train = []
for index, path in df.iterrows():
    img_orig = cv2.imread(path[0])
    frame = cv2.resize(img_orig, (640, 480))
    extracted_face = detectFaceOpenCVDnn(net, frame)
    if (index+1) % 135 == 0:
        print("Processed ", index + 1, "images. Continuing...")
    if len(extracted_face) > 0:
        X_train_final.append(np.asarray(extracted_face))
        Y_train.append(path[1])

print("Done!")
# Out:
# Processed  135 images. Continuing...
# Processed  270 images. Continuing...
# Processed  405 images. Continuing...
# Processed  540 images. Continuing...
# Processed  675 images. Continuing...
# Processed  810 images. Continuing...
# Processed  945 images. Continuing...
# Processed  1080 images. Continuing...
# Processed  1215 images. Continuing...
# Processed  1350 images. Continuing...
# Processed  1485 images. Continuing...
# Processed  1620 images. Continuing...
# Processed  1755 images. Continuing...
# Processed  1890 images. Continuing...
# Processed  2025 images. Continuing...
# Processed  2160 images. Continuing...
# Processed  2295 images. Continuing...
# Processed  2430 images. Continuing...
# Processed  2565 images. Continuing...
# Processed  2700 images. Continuing...
# Processed  2835 images. Continuing...
# Processed  2970 images. Continuing...
# Processed  3105 images. Continuing...
# Processed  3240 images. Continuing...
# Processed  3375 images. Continuing...
# Processed  3510 images. Continuing...
# Processed  3645 images. Continuing...
# Processed  3780 images. Continuing...
# Processed  3915 images. Continuing...
# Processed  4050 images. Continuing...
# Processed  4185 images. Continuing...
# Processed  4320 images. Continuing...
# Processed  4455 images. Continuing...
# Processed  4590 images. Continuing...
# Processed  4725 images. Continuing...
# Processed  4860 images. Continuing...
# Processed  4995 images. Continuing...
# Processed  5130 images. Continuing...
# Processed  5265 images. Continuing...
# Processed  5400 images. Continuing...
# Processed  5535 images. Continuing...
# Processed  5670 images. Continuing...
# Processed  5805 images. Continuing...
# Processed  5940 images. Continuing...
# Processed  6075 images. Continuing...
# Processed  6210 images. Continuing...
# Processed  6345 images. Continuing...
# Processed  6480 images. Continuing...
# Processed  6615 images. Continuing...
# Processed  6750 images. Continuing...
# Processed  6885 images. Continuing...
# Processed  7020 images. Continuing...
# Processed  7155 images. Continuing...
# Processed  7290 images. Continuing...
# Processed  7425 images. Continuing...
# Processed  7560 images. Continuing...
# Processed  7695 images. Continuing...
# Processed  7830 images. Continuing...
# Processed  7965 images. Continuing...
# Processed  8100 images. Continuing...
# Processed  8235 images. Continuing...
# Processed  8370 images. Continuing...
# Processed  8505 images. Continuing...
# Processed  8640 images. Continuing...
# Processed  8775 images. Continuing...
# Processed  8910 images. Continuing...
# Processed  9045 images. Continuing...
# Processed  9180 images. Continuing...
# Processed  9315 images. Continuing...
# Processed  9450 images. Continuing...
# Processed  9585 images. Continuing...
# Processed  9720 images. Continuing...
# Processed  9855 images. Continuing...
# Processed  9990 images. Continuing...
# Processed  10125 images. Continuing...
# Processed  10260 images. Continuing...
# Processed  10395 images. Continuing...
# Processed  10530 images. Continuing...
# Processed  10665 images. Continuing...
# Processed  10800 images. Continuing...
# Processed  10935 images. Continuing...
# Processed  11070 images. Continuing...
# Processed  11205 images. Continuing...
# Processed  11340 images. Continuing...
# Processed  11475 images. Continuing...
# Processed  11610 images. Continuing...
# Processed  11745 images. Continuing...
# Processed  11880 images. Continuing...
# Processed  12015 images. Continuing...
# Processed  12150 images. Continuing...
# Processed  12285 images. Continuing...
# Processed  12420 images. Continuing...
# Processed  12555 images. Continuing...
# Done!

# %%
print(len(X_train_final))
# Out:
# 11827

# %%
np.save("Data/extracted faces/processed_train_imgs.npy", X_train_final)
np.save("Data/extracted faces/train_labels.npy", Y_train)
# Out:
# c:\Users\wamik\miniconda3\lib\site-packages\numpy\lib\npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
X_test_final = []
Y_test = []
for index, path in df_test.iterrows():
    img_orig = cv2.imread(path[0])
    frame = cv2.resize(img_orig, (640, 480))
    extracted_face = detectFaceOpenCVDnn(net, frame)
    if (index+1) % 135 == 0:
        print("Processed ", index + 1, "images. Continuing...")
    if len(extracted_face) > 0:
        X_test_final.append(np.asarray(extracted_face))
        Y_test.append(path[1])

print("Done!")
# Out:
# Processed  135 images. Continuing...
# Processed  270 images. Continuing...
# Processed  405 images. Continuing...
# Processed  540 images. Continuing...
# Processed  675 images. Continuing...
# Processed  810 images. Continuing...
# Processed  945 images. Continuing...
# Processed  1080 images. Continuing...
# Processed  1215 images. Continuing...
# Processed  1350 images. Continuing...
# Processed  1485 images. Continuing...
# Processed  1620 images. Continuing...
# Processed  1755 images. Continuing...
# Processed  1890 images. Continuing...
# Done!

# %%
print(len(X_test_final))
# Out:
# 1800

# %%
np.save("Data/extracted faces/processed_test_data.npy", X_test_final)
np.save("Data/extracted faces/test_labels.npy", Y_test)

# %% [markdown]
# ## Loading Faces Train data

# %%
X_train = np.load("Data/extracted faces/processed_train_imgs.npy", allow_pickle=True)
Y_train = np.load("Data/extracted faces/train_labels.npy")

# %%
X_test = np.load("Data/extracted faces/processed_test_data.npy", allow_pickle=True)
Y_test = np.load("Data/extracted faces/test_labels.npy")

# %%
(X_val, X_test_final, Y_val, Y_test_final) = train_test_split(X_test, Y_test, test_size=0.6, stratify=Y_test, random_state=42)
X_val = np.asarray(X_val)
Y_val = np.asarray(Y_val)
X_test = np.asarray(X_test)
Y_test = np.asarray(Y_test)
print(X_val.shape)
print(Y_val.shape)
# Out:
# (720,)
# (720,)

# %%
X_train_resized = []
Y_train_resized = []
i = 0
for x in X_train:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (80, 120))
        img_blur = cv2.GaussianBlur(img, (3,3), 0)
        edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
        edges = np.asarray(edges)
        edges = edges.reshape(120, 80, 1)
        X_train_resized.append(edges)
        Y_train_resized.append(Y_train[i])
    i+=1
X_train_resized = np.asarray(X_train_resized)
X_train_resized.shape
# Out:
# (11797, 120, 80, 1)

# %%
img_blur = cv2.GaussianBlur(X_train_resized[900], (3,3), 0)
edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
plt.imshow(edges, cmap='gray')

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=Y_train_resized, bins='auto', color='#0504aa')
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Labels')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
Y_train_resized = np_utils.to_categorical(Y_train_resized, 8)
print('New y_train shape: ', Y_train_resized.shape)
# Out:
# New y_train shape:  (11797, 8)

# %%
X_val_resized = []
Y_val_resized = []
i = 0
for x in X_val:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (80, 120))
        img_blur = cv2.GaussianBlur(img, (3,3), 0)
        edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
        edges = np.asarray(edges)
        edges = edges.reshape(120, 80, 1)
        X_val_resized.append(edges)
        Y_val_resized.append(Y_train[i])
    i+=1
X_val_resized = np.asarray(X_val_resized)
X_val_resized.shape
# Out:
# (719, 120, 80, 1)

# %%
Y_val_resized = np_utils.to_categorical(Y_val_resized, 8)
print('New y_train shape: ', Y_val_resized.shape)
# Out:
# New y_train shape:  (719, 8)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(120, 80, 1)))
model.add(layers.MaxPooling2D((4, 4)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((4, 4)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.3))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 118, 78, 32)       320
#
#  max_pooling2d_9 (MaxPooling  (None, 29, 19, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 27, 17, 64)        18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 6, 4, 64)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 1536)              0
#
#  dropout_7 (Dropout)         (None, 1536)              0
#
#  dense_8 (Dense)             (None, 64)                98368
#
#  dense_9 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 117,704
# Trainable params: 117,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor='accuracy', patience=10)
]

opt = keras.optimizers.RMSprop(learning_rate=0.1, momentum=0.9)

model.compile(loss='categorical_crossentropy',
                optimizer=opt, metrics=['accuracy'])

BATCH_SIZE = 100
EPOCHS = 30

history = model.fit(X_train_resized, Y_train_resized, epochs=EPOCHS, batch_size=BATCH_SIZE,callbacks=callbacks_list,
                    validation_data=(X_val_resized, Y_val_resized))
# Out:
# Epoch 1/30
# 118/118 [==============================] - 17s 144ms/step - loss: 21830.6816 - accuracy: 0.1863 - val_loss: 1.7059 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 118/118 [==============================] - 17s 146ms/step - loss: 2.0250 - accuracy: 0.1964 - val_loss: 1.7062 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 118/118 [==============================] - 17s 144ms/step - loss: 2.0281 - accuracy: 0.1915 - val_loss: 2.0506 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 118/118 [==============================] - 17s 144ms/step - loss: 2.0271 - accuracy: 0.1891 - val_loss: 1.5572 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 118/118 [==============================] - 17s 144ms/step - loss: 2.0250 - accuracy: 0.1971 - val_loss: 1.3738 - val_accuracy: 1.0000
# Epoch 6/30
# 118/118 [==============================] - 18s 157ms/step - loss: 2.0257 - accuracy: 0.1928 - val_loss: 1.5854 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 118/118 [==============================] - 19s 159ms/step - loss: 2.0131 - accuracy: 0.1963 - val_loss: 1.4731 - val_accuracy: 1.0000
# Epoch 8/30
# 118/118 [==============================] - 20s 166ms/step - loss: 2.0170 - accuracy: 0.1989 - val_loss: 1.7104 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 118/118 [==============================] - 19s 164ms/step - loss: 2.0225 - accuracy: 0.1873 - val_loss: 1.2856 - val_accuracy: 1.0000
# Epoch 10/30
# 118/118 [==============================] - 19s 164ms/step - loss: 2.0178 - accuracy: 0.1892 - val_loss: 1.5235 - val_accuracy: 1.0000
# Epoch 11/30
# 118/118 [==============================] - 20s 169ms/step - loss: 2.0165 - accuracy: 0.1941 - val_loss: 1.9697 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 118/118 [==============================] - 20s 168ms/step - loss: 2.0228 - accuracy: 0.1914 - val_loss: 1.7874 - val_accuracy: 0.0000e+00
# Epoch 13/30
#  45/118 [==========>...................] - ETA: 12s - loss: 2.0238 - accuracy: 0.1938
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\face extraction.ipynb Cell 30 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X53sZmlsZQ%3D%3D?line=9'>10</a> BATCH_SIZE = 100
#      <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X53sZmlsZQ%3D%3D?line=10'>11</a> EPOCHS = 30
# ---> <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X53sZmlsZQ%3D%3D?line=12'>13</a> history = model.fit(X_train_resized, Y_train_resized, epochs=EPOCHS, batch_size=BATCH_SIZE,callbacks=callbacks_list,
#      <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X53sZmlsZQ%3D%3D?line=13'>14</a>                     validation_data=(X_val_resized, Y_val_resized))
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\engine\training.py:1414, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412 logs = tmp_logs  # No error, now safe to assign to logs.
#    1413 end_step = step + data_handler.step_increment
# -> 1414 callbacks.on_train_batch_end(end_step, logs)
#    1415 if self.stop_training:
#    1416   break
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
# --> 356   hook(batch, logs)
#     358 if self._check_timing:
#     359   if hook_name not in self._hook_times:
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\callbacks.py:1034, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1033 def on_train_batch_end(self, batch, logs=None):
# -> 1034   self._batch_update_progbar(batch, logs)
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\callbacks.py:1106, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1102   self.seen += add_seen
#    1104 if self.verbose == 1:
#    1105   # Only block async when verbose = 1.
# -> 1106   logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\utils\tf_utils.py:607, in sync_to_numpy_or_python_type(tensors)
#     604     return t
#     605   return t.item() if np.ndim(t) == 0 else t
# --> 607 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\wamik\miniconda3\lib\site-packages\tensorflow\python\util\nest.py:916, in map_structure(func, *structure, **kwargs)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File c:\Users\wamik\miniconda3\lib\site-packages\tensorflow\python\util\nest.py:916, in <listcomp>(.0)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File c:\Users\wamik\miniconda3\lib\site-packages\keras\utils\tf_utils.py:601, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     598 def _to_single_numpy_or_python_type(t):
#     599   # Don't turn ragged or sparse tensors to NumPy.
#     600   if isinstance(t, tf.Tensor):
# --> 601     t = t.numpy()
#     602   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     603   if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\wamik\miniconda3\lib\site-packages\tensorflow\python\framework\ops.py:1159, in _EagerTensorBase.numpy(self)
#    1136 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1137
#    1138 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1156     NumPy dtype.
#    1157 """
#    1158 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1159 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1160 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\wamik\miniconda3\lib\site-packages\tensorflow\python\framework\ops.py:1125, in _EagerTensorBase._numpy(self)
#    1123 def _numpy(self):
#    1124   try:
# -> 1125     return self._numpy_internal()
#    1126   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1127     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
# summarize history for accuracy and loss
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data")
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data")
plt.plot(history.history['loss'], "r--", label="Loss of training data")
plt.plot(history.history['val_loss'], "r", label="Loss of validation data")
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\face extraction.ipynb Cell 30 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> # summarize history for accuracy and loss
#       <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X54sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(6, 4))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X54sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data")
#       <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X54sZmlsZQ%3D%3D?line=3'>4</a> plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data")
#       <a href='vscode-notebook-cell:/c%3A/Users/wamik/Documents/Notes%20Y4S2/CS3244/Projects/Project%202/CS3244-Group-8-Project-2/face%20extraction.ipynb#X54sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(history.history['loss'], "r--", label="Loss of training data")
#
# KeyError: 'accuracy'

# %%
X_test_resized = []
Y_test_resized = []
i = 0
for x in X_test_final:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (80, 120))
        X_test_resized.append(img)
        Y_test_resized.append(Y_test_final[i])
    i+=1
X_test_resized = np.asarray(X_test_resized)
X_test_resized.shape
# Out:
# (1069, 120, 80, 3)

# %%
Y_test_resized = np_utils.to_categorical(Y_test_resized, 8)
print('New y_train shape: ', Y_test_resized.shape)
# Out:
# New y_train shape:  (1069, 8)

# %%
score = model.evaluate(X_test_resized, Y_test_resized, verbose=1)

print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 34/34 [==============================] - 1s 30ms/step - loss: 0.4085 - accuracy: 0.1740
#
# Accuracy on test data: 0.17
#
# Loss on test data: 0.41

# %%
LABELS = [0, 1, 2, 3, 4, 5, 6, 7]
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap="coolwarm",
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.show()

# %%
y_pred_test = model.predict(X_test_resized)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = np.argmax(Y_test_resized, axis=1)

show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 34/34 [==============================] - 1s 26ms/step
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.69      0.27       202
#            1       0.42      0.02      0.04       215
#            2       0.20      0.05      0.08       186
#            3       0.00      0.00      0.00       102
#            4       0.36      0.11      0.17        81
#            5       0.05      0.01      0.02        82
#            6       0.00      0.00      0.00        82
#            7       0.19      0.18      0.19       119
#
#     accuracy                           0.17      1069
#    macro avg       0.17      0.13      0.10      1069
# weighted avg       0.20      0.17      0.11      1069
