# %% [markdown]
# # Extracting and Classifying Face Images
#
# https://dev.to/azure/opencv-detect-and-blur-faces-using-dnn-40ab
#
# https://towardsdatascience.com/face-detection-models-which-to-use-and-why-d263e82c302c

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, get_scorer_names, precision_score,recall_score,f1_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import seaborn as sns

# We import the data set from tensorflow and build the model there
import tensorflow as tf
from tensorflow.keras import layers, models
from keras.utils import np_utils
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Import the inception model  
from tensorflow.keras.applications.inception_v3 import InceptionV3

import torch
# If you do not have a GPU or do not want to run this code on your GPU, comment out the following lines
torch.cuda.empty_cache()
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Extracting the Data
#
# The images stored in the combined dataset are extracted into separate train and test set paths.
#
# NOTE: Before running this file, please unzip the Distacted Driver Dataset that contains the combined dataset.

# %%
PARENT_PATH = os.getcwd()
DATA_PATH = os.path.join(os.getcwd(), "Combined New")
TEST_PATH = os.path.join(DATA_PATH, "test")
TRAIN_PATH = os.path.join(DATA_PATH, "train")
UNSEEN_PATH = os.path.join(DATA_PATH, "unseen")
NUM_CLASSES = 8
TRAIN_PATH
# Out:
# 'c:\\Users\\wamik\\Documents\\Notes Y4S2\\CS3244\\Projects\\Project 2\\CS3244-Group-8-Project-2\\Combined New\\train'

# %%
CLASS = [["c0", "Safe Driving"], ["c1", "Text"], ["c2", "Phone"], 
         ["c3", "Adjusting Radio"], ["c4", "Drinking"], 
         ["c5", "Reaching Behind"], ["c6", "Hair or Makeup"], 
         ["c7", "Talking to Passenger"]]
TEST_CLS = [os.path.join(os.getcwd(), TEST_PATH, cls[0]) for cls in CLASS]
TRAIN_CLS = [os.path.join(os.getcwd(), TRAIN_PATH, cls[0]) for cls in CLASS]
for cls_path in TEST_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
for cls_path in TRAIN_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
# Out:
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c0
# 711
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c1
# 667
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c2
# 602
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c3
# 264
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c4
# 255
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c5
# 243
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c6
# 242
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c7
# 430
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c0
# 2131
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c1
# 2000
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c2
# 1805
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c3
# 791
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c4
# 762
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c5
# 726
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c6
# 723
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c7
# 1287

# %% [markdown]
# For each class, the path of the training and test data is stored in separate lists. The corresponding labels are also stored in a different list

# %%
train_paths = []
test_paths = []
for cls in range(NUM_CLASSES):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    train_paths.append(os.path.join(TRAIN_CLS[cls], train_instance))
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_paths.append(os.path.join(TEST_CLS[cls], test_instance))

# %%
classes = []
test_classes = []
for cls in range(NUM_CLASSES):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    classes.append(cls)
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_classes.append(cls)

# %% [markdown]
# Then separate dataframes storing the train and test paths with their corresponding labels are created.

# %%
df = pd.DataFrame({
  'filename': train_paths,
  'class': classes
})
df
# Out:
#                                                 filename  class
# 0      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                  ...    ...
# 10220  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10221  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10222  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10223  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10224  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [10225 rows x 2 columns]

# %%
df_test = pd.DataFrame({
  'filename': test_paths,
  'class': test_classes
})
df_test
# Out:
#                                                filename  class
# 0     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                 ...    ...
# 3409  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3410  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3411  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3412  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3413  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [3414 rows x 2 columns]

# %%
# -----------------------------------------------
# Face Detection using DNN Net
# -----------------------------------------------
# detect faces using a DNN model 
# download model and prototxt from https://github.com/spmallick/learnopencv/tree/master/FaceDetectionComparison/models

def detectFaceOpenCVDnn(net, frame):
    
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]
    blob = cv2.dnn.blobFromImage(frame, 1.0, mean = [104, 117, 123])

    net.setInput(blob)
    detections = net.forward()
    conf_threshold = 0.1
    box = None
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            conf_threshold = confidence
            x1 = int(detections[0, 0, i, 3] * frameWidth)
            y1 = int(detections[0, 0, i, 4] * frameHeight)
            x2 = int(detections[0, 0, i, 5] * frameWidth)
            y2 = int(detections[0, 0, i, 6] * frameHeight)
            box = [x1, y1, x2, y2]

    if box == None:
        return []
    # extract the face
    face_boundary = frame[box[1]:box[3], box[0]:box[2]]

    return face_boundary

# %%
# load face detection model
modelFile = "models/res10_300x300_ssd_iter_140000_fp16.caffemodel"
configFile = "models/deploy.prototxt"
net = cv2.dnn.readNetFromCaffe(configFile, modelFile)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

img_orig = cv2.imread(df['filename'].iloc[10000])
plt.imshow(img_orig)
plt.show()
frame = cv2.resize(img_orig, (640, 480))

extracted_face = detectFaceOpenCVDnn(net, frame)
plt.imshow(extracted_face)
plt.show()

# %%
X_train_final = []
Y_train = []
for index, path in df.iterrows():
    img_orig = cv2.imread(path[0])
    frame = cv2.resize(img_orig, (640, 480))
    extracted_face = detectFaceOpenCVDnn(net, frame)
    if (index+1) % 135 == 0:
        print("Processed ", index + 1, "images. Continuing...")
    if len(extracted_face) > 0:
        X_train_final.append(np.asarray(extracted_face))
        Y_train.append(path[1])

print("Done!")
# Out:
# Processed  135 images. Continuing...
# Processed  270 images. Continuing...
# Processed  405 images. Continuing...
# Processed  540 images. Continuing...
# Processed  675 images. Continuing...
# Processed  810 images. Continuing...
# Processed  945 images. Continuing...
# Processed  1080 images. Continuing...
# Processed  1215 images. Continuing...
# Processed  1350 images. Continuing...
# Processed  1485 images. Continuing...
# Processed  1620 images. Continuing...
# Processed  1755 images. Continuing...
# Processed  1890 images. Continuing...
# Processed  2025 images. Continuing...
# Processed  2160 images. Continuing...
# Processed  2295 images. Continuing...
# Processed  2430 images. Continuing...
# Processed  2565 images. Continuing...
# Processed  2700 images. Continuing...
# Processed  2835 images. Continuing...
# Processed  2970 images. Continuing...
# Processed  3105 images. Continuing...
# Processed  3240 images. Continuing...
# Processed  3375 images. Continuing...
# Processed  3510 images. Continuing...
# Processed  3645 images. Continuing...
# Processed  3780 images. Continuing...
# Processed  3915 images. Continuing...
# Processed  4050 images. Continuing...
# Processed  4185 images. Continuing...
# Processed  4320 images. Continuing...
# Processed  4455 images. Continuing...
# Processed  4590 images. Continuing...
# Processed  4725 images. Continuing...
# Processed  4860 images. Continuing...
# Processed  4995 images. Continuing...
# Processed  5130 images. Continuing...
# Processed  5265 images. Continuing...
# Processed  5400 images. Continuing...
# Processed  5535 images. Continuing...
# Processed  5670 images. Continuing...
# Processed  5805 images. Continuing...
# Processed  5940 images. Continuing...
# Processed  6075 images. Continuing...
# Processed  6210 images. Continuing...
# Processed  6345 images. Continuing...
# Processed  6480 images. Continuing...
# Processed  6615 images. Continuing...
# Processed  6750 images. Continuing...
# Processed  6885 images. Continuing...
# Processed  7020 images. Continuing...
# Processed  7155 images. Continuing...
# Processed  7290 images. Continuing...
# Processed  7425 images. Continuing...
# Processed  7560 images. Continuing...
# Processed  7695 images. Continuing...
# Processed  7830 images. Continuing...
# Processed  7965 images. Continuing...
# Processed  8100 images. Continuing...
# Processed  8235 images. Continuing...
# Processed  8370 images. Continuing...
# Processed  8505 images. Continuing...
# Processed  8640 images. Continuing...
# Processed  8775 images. Continuing...
# Processed  8910 images. Continuing...
# Processed  9045 images. Continuing...
# Processed  9180 images. Continuing...
# Processed  9315 images. Continuing...
# Processed  9450 images. Continuing...
# Processed  9585 images. Continuing...
# Processed  9720 images. Continuing...
# Processed  9855 images. Continuing...
# Processed  9990 images. Continuing...
# Processed  10125 images. Continuing...
# Done!

# %%
print(len(X_train_final))
# Out:
# 9587

# %%
np.save("Data/combined new faces/processed_train_imgs.npy", X_train_final)
np.save("Data/combined new faces/train_labels.npy", Y_train)
# Out:
# c:\Users\wamik\miniconda3\lib\site-packages\numpy\lib\npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
X_test_final = []
Y_val = []
for index, path in df_test.iterrows():
    img_orig = cv2.imread(path[0])
    if img_orig is not None:
        frame = cv2.resize(img_orig, (640, 480))
        extracted_face = detectFaceOpenCVDnn(net, frame)
        if (index+1) % 135 == 0:
            print("Processed ", index + 1, "images. Continuing...")
        if len(extracted_face) > 0:
            X_test_final.append(np.asarray(extracted_face))
            Y_val.append(path[1])

print("Done!")
# Out:
# Processed  135 images. Continuing...
# Processed  270 images. Continuing...
# Processed  405 images. Continuing...
# Processed  540 images. Continuing...
# Processed  675 images. Continuing...
# Processed  810 images. Continuing...
# Processed  945 images. Continuing...
# Processed  1080 images. Continuing...
# Processed  1215 images. Continuing...
# Processed  1350 images. Continuing...
# Processed  1485 images. Continuing...
# Processed  1620 images. Continuing...
# Processed  1755 images. Continuing...
# Processed  1890 images. Continuing...
# Processed  2025 images. Continuing...
# Processed  2160 images. Continuing...
# Processed  2295 images. Continuing...
# Processed  2430 images. Continuing...
# Processed  2565 images. Continuing...
# Processed  2700 images. Continuing...
# Processed  2835 images. Continuing...
# Processed  2970 images. Continuing...
# Processed  3105 images. Continuing...
# Processed  3240 images. Continuing...
# Processed  3375 images. Continuing...
# Done!

# %%
print(len(X_test_final))
# Out:
# 3225

# %%
np.save("Data/combined new faces/processed_test_data.npy", X_test_final)
np.save("Data/combined new faces/test_labels.npy", Y_val)
# Out:
# c:\Users\wamik\miniconda3\lib\site-packages\numpy\lib\npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %% [markdown]
# ## Loading Faces Train data

# %%
X_train = np.load("Data/combined new faces/processed_train_imgs.npy", allow_pickle=True)
Y_train = np.load("Data/combined new faces/train_labels.npy")

# %%
X_test = np.load("Data/combined new faces/processed_test_data.npy", allow_pickle=True)
Y_test = np.load("Data/combined new faces/test_labels.npy")

# %%
X_train_resized = []
Y_train_resized = []
i = 0
for x in X_train:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (75, 100))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        # img_blur = cv2.GaussianBlur(img, (3,3), 0)
        # edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
        # edges = np.asarray(edges)
        # edges = edges.reshape(120, 80, 1)
        X_train_resized.append(img/255.0)
        Y_train_resized.append(Y_train[i])
    i+=1
X_train_resized = np.asarray(X_train_resized)
X_train_resized = X_train_resized.reshape(-1, 100, 75, 1)
X_train_resized.shape
# Out:
# (9564, 100, 75, 1)

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=Y_train_resized, bins='auto', color='#0504aa')
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Labels')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
(X_train, X_val, Y_train, Y_val) = train_test_split(X_train_resized, Y_train_resized, test_size=0.2, stratify=Y_train_resized, random_state=42)
X_train = np.asarray(X_train)
Y_train = np.asarray(Y_train)
X_val = np.asarray(X_val)
Y_val = np.asarray(Y_val)
print(X_val.shape)
print(Y_val.shape)
# Out:
# (1913, 100, 75, 1)
# (1913,)

# %%
Y_train_resized = np_utils.to_categorical(Y_train, 8)
print('New y_train shape: ', Y_train_resized.shape)
Y_val_resized = np_utils.to_categorical(Y_val, 8)
print('New y_val shape: ', Y_val_resized.shape)
# Out:
# New y_train shape:  (7651, 8)
# New y_val shape:  (1913, 8)

# %%
X_test_resized = []
Y_test_resized = []
i = 0
for x in X_test:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (75, 100))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        X_test_resized.append(img/255)
        Y_test_resized.append(Y_test[i])
    i+=1
X_test_resized = np.asarray(X_test_resized)
X_test_resized = X_test_resized.reshape(-1, 100, 75, 1)
X_test_resized.shape
# Out:
# (3216, 100, 75, 1)

# %%
Y_test_resized = np_utils.to_categorical(Y_test_resized, 8)
print('New y_test shape: ', Y_test_resized.shape)
# Out:
# New y_test shape:  (3216, 8)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (2, 2), activation='relu', input_shape=(100, 75, 1)))
model.add(layers.MaxPooling2D((3, 3)))
model.add(layers.Conv2D(16, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((4, 4)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.4))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_196 (Conv2D)         (None, 99, 74, 32)        160
#
#  max_pooling2d_16 (MaxPoolin  (None, 33, 24, 32)       0
#  g2D)
#
#  conv2d_197 (Conv2D)         (None, 31, 22, 16)        4624
#
#  max_pooling2d_17 (MaxPoolin  (None, 7, 5, 16)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 560)               0
#
#  dropout_7 (Dropout)         (None, 560)               0
#
#  dense_14 (Dense)            (None, 64)                35904
#
#  dense_15 (Dense)            (None, 8)                 520
#
# =================================================================
# Total params: 41,208
# Trainable params: 41,208
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor='accuracy', patience=5)
]

opt = keras.optimizers.SGD(learning_rate=0.01)

model.compile(loss='categorical_crossentropy',
                optimizer=opt, metrics=['accuracy'])

BATCH_SIZE = 30
EPOCHS = 100

history = model.fit(X_train, Y_train_resized, epochs=EPOCHS, batch_size=BATCH_SIZE,callbacks=callbacks_list,
                    validation_data=(X_val, Y_val_resized))
# Out:
# Epoch 1/100
# 256/256 [==============================] - 7s 23ms/step - loss: 2.0267 - accuracy: 0.2000 - val_loss: 1.9748 - val_accuracy: 0.2164
# Epoch 2/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.9750 - accuracy: 0.2032 - val_loss: 1.9624 - val_accuracy: 0.2718
# Epoch 3/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.9618 - accuracy: 0.2253 - val_loss: 1.9453 - val_accuracy: 0.2258
# Epoch 4/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.9431 - accuracy: 0.2238 - val_loss: 1.9217 - val_accuracy: 0.2520
# Epoch 5/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.9163 - accuracy: 0.2457 - val_loss: 1.8987 - val_accuracy: 0.2410
# Epoch 6/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.8927 - accuracy: 0.2689 - val_loss: 1.8542 - val_accuracy: 0.3079
# Epoch 7/100
# 256/256 [==============================] - 5s 21ms/step - loss: 1.8622 - accuracy: 0.2869 - val_loss: 1.8195 - val_accuracy: 0.3246
# Epoch 8/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.8454 - accuracy: 0.2990 - val_loss: 1.8272 - val_accuracy: 0.3079
# Epoch 9/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.8278 - accuracy: 0.3015 - val_loss: 1.7809 - val_accuracy: 0.3304
# Epoch 10/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.8138 - accuracy: 0.3115 - val_loss: 1.8027 - val_accuracy: 0.2880
# Epoch 11/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.7956 - accuracy: 0.3202 - val_loss: 1.7597 - val_accuracy: 0.3372
# Epoch 12/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.7868 - accuracy: 0.3245 - val_loss: 1.7749 - val_accuracy: 0.3262
# Epoch 13/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.7742 - accuracy: 0.3311 - val_loss: 1.7384 - val_accuracy: 0.3534
# Epoch 14/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.7565 - accuracy: 0.3409 - val_loss: 1.7310 - val_accuracy: 0.3366
# Epoch 15/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.7388 - accuracy: 0.3487 - val_loss: 1.6935 - val_accuracy: 0.3873
# Epoch 16/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.7234 - accuracy: 0.3580 - val_loss: 1.6836 - val_accuracy: 0.4020
# Epoch 17/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.7116 - accuracy: 0.3647 - val_loss: 1.7549 - val_accuracy: 0.3063
# Epoch 18/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.6823 - accuracy: 0.3763 - val_loss: 1.6816 - val_accuracy: 0.3727
# Epoch 19/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.6622 - accuracy: 0.3894 - val_loss: 1.6114 - val_accuracy: 0.4208
# Epoch 20/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.6396 - accuracy: 0.4011 - val_loss: 1.6426 - val_accuracy: 0.3978
# Epoch 21/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.6148 - accuracy: 0.4064 - val_loss: 1.5404 - val_accuracy: 0.4490
# Epoch 22/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.5840 - accuracy: 0.4148 - val_loss: 1.5313 - val_accuracy: 0.4412
# Epoch 23/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.5753 - accuracy: 0.4288 - val_loss: 1.5601 - val_accuracy: 0.4328
# Epoch 24/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.5493 - accuracy: 0.4368 - val_loss: 1.6321 - val_accuracy: 0.3372
# Epoch 25/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.5296 - accuracy: 0.4396 - val_loss: 1.7446 - val_accuracy: 0.3685
# Epoch 26/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.5244 - accuracy: 0.4454 - val_loss: 1.4438 - val_accuracy: 0.4856
# Epoch 27/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.5056 - accuracy: 0.4546 - val_loss: 1.4824 - val_accuracy: 0.4631
# Epoch 28/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.4878 - accuracy: 0.4569 - val_loss: 1.6060 - val_accuracy: 0.3853
# Epoch 29/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.4733 - accuracy: 0.4673 - val_loss: 1.6757 - val_accuracy: 0.4041
# Epoch 30/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.4646 - accuracy: 0.4744 - val_loss: 1.4613 - val_accuracy: 0.4417
# Epoch 31/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.4482 - accuracy: 0.4799 - val_loss: 1.3759 - val_accuracy: 0.5029
# Epoch 32/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.4378 - accuracy: 0.4833 - val_loss: 1.5331 - val_accuracy: 0.4307
# Epoch 33/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.4325 - accuracy: 0.4795 - val_loss: 1.3655 - val_accuracy: 0.5024
# Epoch 34/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.4160 - accuracy: 0.4914 - val_loss: 1.7217 - val_accuracy: 0.3361
# Epoch 35/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.4075 - accuracy: 0.4951 - val_loss: 1.3539 - val_accuracy: 0.5144
# Epoch 36/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.3803 - accuracy: 0.5054 - val_loss: 1.3637 - val_accuracy: 0.4935
# Epoch 37/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.3749 - accuracy: 0.5079 - val_loss: 1.3159 - val_accuracy: 0.5395
# Epoch 38/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.3623 - accuracy: 0.5109 - val_loss: 1.2763 - val_accuracy: 0.5473
# Epoch 39/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.3496 - accuracy: 0.5168 - val_loss: 1.3899 - val_accuracy: 0.4783
# Epoch 40/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.3320 - accuracy: 0.5198 - val_loss: 1.3097 - val_accuracy: 0.5170
# Epoch 41/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.3310 - accuracy: 0.5286 - val_loss: 1.2640 - val_accuracy: 0.5389
# Epoch 42/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.3215 - accuracy: 0.5276 - val_loss: 1.2277 - val_accuracy: 0.5656
# Epoch 43/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.3050 - accuracy: 0.5325 - val_loss: 1.2351 - val_accuracy: 0.5761
# Epoch 44/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.2991 - accuracy: 0.5390 - val_loss: 1.2031 - val_accuracy: 0.5787
# Epoch 45/100
# 256/256 [==============================] - 6s 24ms/step - loss: 1.2918 - accuracy: 0.5378 - val_loss: 1.3535 - val_accuracy: 0.5055
# Epoch 46/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.2776 - accuracy: 0.5491 - val_loss: 1.1876 - val_accuracy: 0.5907
# Epoch 47/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.2661 - accuracy: 0.5483 - val_loss: 1.2820 - val_accuracy: 0.5510
# Epoch 48/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.2438 - accuracy: 0.5571 - val_loss: 1.1790 - val_accuracy: 0.5912
# Epoch 49/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.2489 - accuracy: 0.5551 - val_loss: 1.1858 - val_accuracy: 0.5766
# Epoch 50/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.2433 - accuracy: 0.5602 - val_loss: 1.4819 - val_accuracy: 0.5086
# Epoch 51/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.2228 - accuracy: 0.5722 - val_loss: 1.2699 - val_accuracy: 0.5238
# Epoch 52/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.2130 - accuracy: 0.5714 - val_loss: 1.2098 - val_accuracy: 0.5625
# Epoch 53/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.2055 - accuracy: 0.5750 - val_loss: 1.1300 - val_accuracy: 0.6111
# Epoch 54/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.2047 - accuracy: 0.5722 - val_loss: 1.1568 - val_accuracy: 0.5834
# Epoch 55/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.1881 - accuracy: 0.5850 - val_loss: 1.1626 - val_accuracy: 0.5797
# Epoch 56/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.1772 - accuracy: 0.5869 - val_loss: 1.1231 - val_accuracy: 0.6153
# Epoch 57/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.1695 - accuracy: 0.5872 - val_loss: 1.2185 - val_accuracy: 0.5395
# Epoch 58/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.1659 - accuracy: 0.5853 - val_loss: 1.0891 - val_accuracy: 0.6215
# Epoch 59/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.1479 - accuracy: 0.6008 - val_loss: 1.3222 - val_accuracy: 0.5071
# Epoch 60/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.1528 - accuracy: 0.5923 - val_loss: 1.0772 - val_accuracy: 0.6330
# Epoch 61/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.1458 - accuracy: 0.5984 - val_loss: 2.9933 - val_accuracy: 0.2060
# Epoch 62/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.1616 - accuracy: 0.5947 - val_loss: 1.1031 - val_accuracy: 0.6210
# Epoch 63/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.1354 - accuracy: 0.6049 - val_loss: 1.0854 - val_accuracy: 0.6430
# Epoch 64/100
# 256/256 [==============================] - 6s 25ms/step - loss: 1.1105 - accuracy: 0.6116 - val_loss: 1.2498 - val_accuracy: 0.5630
# Epoch 65/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.1065 - accuracy: 0.6172 - val_loss: 1.0319 - val_accuracy: 0.6440
# Epoch 66/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0972 - accuracy: 0.6133 - val_loss: 1.0281 - val_accuracy: 0.6519
# Epoch 67/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0864 - accuracy: 0.6219 - val_loss: 1.1763 - val_accuracy: 0.5630
# Epoch 68/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0778 - accuracy: 0.6223 - val_loss: 1.3168 - val_accuracy: 0.5227
# Epoch 69/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0773 - accuracy: 0.6216 - val_loss: 1.0519 - val_accuracy: 0.6566
# Epoch 70/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.0608 - accuracy: 0.6268 - val_loss: 1.0352 - val_accuracy: 0.6362
# Epoch 71/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0691 - accuracy: 0.6317 - val_loss: 0.9888 - val_accuracy: 0.6665
# Epoch 72/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0458 - accuracy: 0.6366 - val_loss: 0.9777 - val_accuracy: 0.6827
# Epoch 73/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0511 - accuracy: 0.6327 - val_loss: 0.9778 - val_accuracy: 0.6801
# Epoch 74/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0344 - accuracy: 0.6317 - val_loss: 1.0489 - val_accuracy: 0.6597
# Epoch 75/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0229 - accuracy: 0.6436 - val_loss: 0.9867 - val_accuracy: 0.6686
# Epoch 76/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0317 - accuracy: 0.6448 - val_loss: 0.9757 - val_accuracy: 0.6837
# Epoch 77/100
# 256/256 [==============================] - 6s 23ms/step - loss: 1.0113 - accuracy: 0.6476 - val_loss: 0.9589 - val_accuracy: 0.6921
# Epoch 78/100
# 256/256 [==============================] - 6s 22ms/step - loss: 1.0043 - accuracy: 0.6536 - val_loss: 1.0484 - val_accuracy: 0.6294
# Epoch 79/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9974 - accuracy: 0.6529 - val_loss: 1.0058 - val_accuracy: 0.6681
# Epoch 80/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9898 - accuracy: 0.6570 - val_loss: 1.2604 - val_accuracy: 0.5531
# Epoch 81/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9979 - accuracy: 0.6522 - val_loss: 0.9306 - val_accuracy: 0.6973
# Epoch 82/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9967 - accuracy: 0.6569 - val_loss: 1.0648 - val_accuracy: 0.6194
# Epoch 83/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9849 - accuracy: 0.6535 - val_loss: 1.1718 - val_accuracy: 0.5964
# Epoch 84/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9853 - accuracy: 0.6578 - val_loss: 0.9233 - val_accuracy: 0.6926
# Epoch 85/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9591 - accuracy: 0.6666 - val_loss: 0.9876 - val_accuracy: 0.6722
# Epoch 86/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9659 - accuracy: 0.6685 - val_loss: 1.5921 - val_accuracy: 0.4778
# Epoch 87/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9669 - accuracy: 0.6654 - val_loss: 0.9465 - val_accuracy: 0.6717
# Epoch 88/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9491 - accuracy: 0.6766 - val_loss: 0.9544 - val_accuracy: 0.6817
# Epoch 89/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9322 - accuracy: 0.6738 - val_loss: 0.9304 - val_accuracy: 0.6911
# Epoch 90/100
# 256/256 [==============================] - 6s 22ms/step - loss: 0.9428 - accuracy: 0.6717 - val_loss: 0.8926 - val_accuracy: 0.7109
# Epoch 91/100
# 256/256 [==============================] - 6s 22ms/step - loss: 0.9286 - accuracy: 0.6766 - val_loss: 0.9938 - val_accuracy: 0.6749
# Epoch 92/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9301 - accuracy: 0.6787 - val_loss: 0.9365 - val_accuracy: 0.6869
# Epoch 93/100
# 256/256 [==============================] - 6s 24ms/step - loss: 0.9150 - accuracy: 0.6849 - val_loss: 1.2796 - val_accuracy: 0.5646
# Epoch 94/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9566 - accuracy: 0.6679 - val_loss: 1.0624 - val_accuracy: 0.6242
# Epoch 95/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9416 - accuracy: 0.6706 - val_loss: 0.8797 - val_accuracy: 0.7078
# Epoch 96/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9290 - accuracy: 0.6803 - val_loss: 0.8965 - val_accuracy: 0.7041
# Epoch 97/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9121 - accuracy: 0.6780 - val_loss: 0.8882 - val_accuracy: 0.7162
# Epoch 98/100
# 256/256 [==============================] - 6s 23ms/step - loss: 0.9118 - accuracy: 0.6812 - val_loss: 0.8905 - val_accuracy: 0.7146

# %%
# summarize history for accuracy and loss
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data")
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data")
plt.plot(history.history['loss'], "r--", label="Loss of training data")
plt.plot(history.history['val_loss'], "r", label="Loss of validation data")
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# %%
score = model.evaluate(X_test_resized, Y_test_resized, verbose=1)

print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 101/101 [==============================] - 1s 9ms/step - loss: 0.9162 - accuracy: 0.7009
#
# Accuracy on test data: 0.70
#
# Loss on test data: 0.92

# %%
LABELS = [0, 1, 2, 3, 4, 5, 6, 7]
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap="coolwarm",
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.show()

# %%
y_pred_test = model.predict(X_test_resized)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = np.argmax(Y_test_resized, axis=1)

show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 101/101 [==============================] - 1s 8ms/step
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.77      0.74       658
#            1       0.64      0.83      0.72       641
#            2       0.76      0.64      0.69       563
#            3       0.67      0.59      0.63       251
#            4       0.79      0.59      0.68       243
#            5       0.62      0.35      0.45       220
#            6       0.61      0.36      0.45       219
#            7       0.76      0.97      0.85       421
#
#     accuracy                           0.70      3216
#    macro avg       0.69      0.64      0.65      3216
# weighted avg       0.70      0.70      0.69      3216

# %%
model.save("best_model_face_cnn.h5")

# %% [markdown]
# ## Preparing Data For Transfer Learning
# ### Saving Data As Images

# %%
for i in range(X_train.shape[0]):
    x = X_train[i]*255
    if len(x)!=0 and len(x[0])!=0:   
        cv2.imwrite("Data/combined new faces/train/" + str(Y_train[i]) + "/" + str(i) + ".jpg", x)

# %%
for i in range(X_val.shape[0]):
    x_val = X_val[i]*255
    if len(x_val)!=0 and len(x_val[0])!=0:   
        cv2.imwrite("Data/combined new faces/val/" + str(Y_val[i]) + "/" + str(i) + ".jpg", x_val)

# %%
Y_test = [np.argmax(y, axis=None, out=None) for y in Y_test_resized]
for i in range(X_test_resized.shape[0]):
    x_test = X_test_resized[i]*255
    if len(x_test)!=0 and len(x_test[0])!=0:   
        cv2.imwrite("Data/combined new faces/test/" + str(Y_test[i]) + "/" + str(i) + ".jpg", x_test)

# %% [markdown]
# ## Transfer Learning with TensorFlow Keras
#
# https://github.com/tejanirla/image_classification/blob/master/transfer_learning.ipynb

# %%
train_dir = "Data/combined new faces/train"
val_dir = "Data/combined new faces/val"
test_dir = "Data/combined new faces/test"
# Add our data-augmentation parameters to ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255.,
                                   width_shift_range = 0.02,
                                   height_shift_range = 0.02,
                                   horizontal_flip = False)

# Note that the validation data should not be augmented!
val_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Note that the test data should not be augmented!
test_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Flow training images in batches of 40 using train_datagen generator
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size = 40,
                                                    class_mode = 'categorical', 
                                                    target_size = (100, 75), shuffle = True)   
# Flow validation images in batches of 40 using val_datagen generator
val_generator =  val_datagen.flow_from_directory( val_dir,
                                                          batch_size  = 40,
                                                          class_mode  = 'categorical', 
                                                          target_size = (100, 75), shuffle = True)  

# Flow validation images in batches of 40 using test_datagen generator
test_generator =  test_datagen.flow_from_directory( test_dir,
                                                          batch_size  = 40,
                                                          class_mode  = 'categorical', 
                                                          target_size = (100, 75), shuffle = False)
# Out:
# Found 7651 images belonging to 8 classes.
# Found 1913 images belonging to 8 classes.
# Found 3216 images belonging to 8 classes.

# %%
pre_trained_model = InceptionV3(input_shape = (100, 75, 3), # Shape of our images
                                include_top = False, # Leave out the last fully connected layer
                                weights = 'imagenet')
for layer in pre_trained_model.layers:
    layer.trainable = True

# %% [markdown]
# https://github.com/tejanirla/image_classification/blob/master/transfer_learning.ipynb

# %%
last_layer = pre_trained_model.get_layer('mixed4') #Only use layers including and above 'mixed4'
last_op = last_layer.output
# Flatten the output layer to 1 dimension
x = layers.Flatten()(last_op)
# # Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)                  
# Add a final sigmoid layer for classification
x = layers.Dense  (8, activation='softmax')(x)           

model = keras.Model(pre_trained_model.input, x) 

model.compile(optimizer = keras.optimizers.SGD(learning_rate=0.01), 
              loss = 'categorical_crossentropy', 
              metrics = ['acc'])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('acc')>0.95):
      print("\nReached 95% accuracy so cancelling training!")
      self.model.stop_training = True

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor='val_acc', patience=10)
]

history = model.fit(
            train_generator,
            validation_data = val_generator,
            steps_per_epoch = 20,
            epochs = 200,
            validation_steps = 20,
            verbose = 2,
            callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 20/20 - 15s - loss: 1.9095 - acc: 0.3035 - val_loss: 1.6996 - val_acc: 0.4175 - 15s/epoch - 730ms/step
# Epoch 2/200
# 20/20 - 4s - loss: 1.6395 - acc: 0.4187 - val_loss: 1.4762 - val_acc: 0.4538 - 4s/epoch - 213ms/step
# Epoch 3/200
# 20/20 - 4s - loss: 1.4405 - acc: 0.4925 - val_loss: 1.4548 - val_acc: 0.4675 - 4s/epoch - 210ms/step
# Epoch 4/200
# 20/20 - 4s - loss: 1.3802 - acc: 0.5163 - val_loss: 1.2691 - val_acc: 0.5725 - 4s/epoch - 201ms/step
# Epoch 5/200
# 20/20 - 4s - loss: 1.2280 - acc: 0.5738 - val_loss: 1.2373 - val_acc: 0.5838 - 4s/epoch - 201ms/step
# Epoch 6/200
# 20/20 - 4s - loss: 1.2469 - acc: 0.5750 - val_loss: 1.1785 - val_acc: 0.6100 - 4s/epoch - 202ms/step
# Epoch 7/200
# 20/20 - 4s - loss: 1.1519 - acc: 0.5838 - val_loss: 1.1848 - val_acc: 0.5987 - 4s/epoch - 215ms/step
# Epoch 8/200
# 20/20 - 4s - loss: 1.0018 - acc: 0.6525 - val_loss: 1.0897 - val_acc: 0.6463 - 4s/epoch - 197ms/step
# Epoch 9/200
# 20/20 - 4s - loss: 1.0598 - acc: 0.6450 - val_loss: 1.0380 - val_acc: 0.6650 - 4s/epoch - 198ms/step
# Epoch 10/200
# 20/20 - 4s - loss: 1.0727 - acc: 0.6524 - val_loss: 0.9085 - val_acc: 0.7038 - 4s/epoch - 193ms/step
# Epoch 11/200
# 20/20 - 4s - loss: 0.9522 - acc: 0.6938 - val_loss: 0.9402 - val_acc: 0.6637 - 4s/epoch - 195ms/step
# Epoch 12/200
# 20/20 - 4s - loss: 0.9554 - acc: 0.6812 - val_loss: 0.9477 - val_acc: 0.6875 - 4s/epoch - 198ms/step
# Epoch 13/200
# 20/20 - 4s - loss: 0.9501 - acc: 0.6825 - val_loss: 0.9210 - val_acc: 0.7163 - 4s/epoch - 200ms/step
# Epoch 14/200
# 20/20 - 4s - loss: 0.8508 - acc: 0.7050 - val_loss: 0.8334 - val_acc: 0.7237 - 4s/epoch - 207ms/step
# Epoch 15/200
# 20/20 - 4s - loss: 0.8327 - acc: 0.7300 - val_loss: 0.8925 - val_acc: 0.6988 - 4s/epoch - 209ms/step
# Epoch 16/200
# 20/20 - 4s - loss: 0.8319 - acc: 0.7188 - val_loss: 0.8188 - val_acc: 0.7350 - 4s/epoch - 213ms/step
# Epoch 17/200
# 20/20 - 4s - loss: 0.7416 - acc: 0.7588 - val_loss: 0.8357 - val_acc: 0.7212 - 4s/epoch - 199ms/step
# Epoch 18/200
# 20/20 - 4s - loss: 0.7437 - acc: 0.7700 - val_loss: 0.7980 - val_acc: 0.7325 - 4s/epoch - 200ms/step
# Epoch 19/200
# 20/20 - 4s - loss: 0.7274 - acc: 0.7663 - val_loss: 0.7537 - val_acc: 0.7788 - 4s/epoch - 204ms/step
# Epoch 20/200
# 20/20 - 4s - loss: 0.7258 - acc: 0.7700 - val_loss: 0.7479 - val_acc: 0.7437 - 4s/epoch - 200ms/step
# Epoch 21/200
# 20/20 - 4s - loss: 0.7256 - acc: 0.7538 - val_loss: 0.7736 - val_acc: 0.7500 - 4s/epoch - 199ms/step
# Epoch 22/200
# 20/20 - 4s - loss: 0.6883 - acc: 0.7886 - val_loss: 0.6840 - val_acc: 0.7800 - 4s/epoch - 196ms/step
# Epoch 23/200
# 20/20 - 4s - loss: 0.6164 - acc: 0.8087 - val_loss: 0.6412 - val_acc: 0.7937 - 4s/epoch - 200ms/step
# Epoch 24/200
# 20/20 - 4s - loss: 0.6488 - acc: 0.7912 - val_loss: 0.6714 - val_acc: 0.7788 - 4s/epoch - 206ms/step
# Epoch 25/200
# 20/20 - 4s - loss: 0.6568 - acc: 0.7825 - val_loss: 0.6558 - val_acc: 0.7887 - 4s/epoch - 200ms/step
# Epoch 26/200
# 20/20 - 4s - loss: 0.5579 - acc: 0.8175 - val_loss: 0.6259 - val_acc: 0.7887 - 4s/epoch - 202ms/step
# Epoch 27/200
# 20/20 - 4s - loss: 0.5842 - acc: 0.8238 - val_loss: 0.6455 - val_acc: 0.7763 - 4s/epoch - 201ms/step
# Epoch 28/200
# 20/20 - 4s - loss: 0.5619 - acc: 0.8262 - val_loss: 0.6790 - val_acc: 0.7788 - 4s/epoch - 194ms/step
# Epoch 29/200
# 20/20 - 4s - loss: 0.4847 - acc: 0.8550 - val_loss: 0.6478 - val_acc: 0.7837 - 4s/epoch - 201ms/step
# Epoch 30/200
# 20/20 - 4s - loss: 0.5096 - acc: 0.8313 - val_loss: 0.6336 - val_acc: 0.7925 - 4s/epoch - 205ms/step
# Epoch 31/200
# 20/20 - 4s - loss: 0.4906 - acc: 0.8438 - val_loss: 0.6075 - val_acc: 0.7987 - 4s/epoch - 204ms/step
# Epoch 32/200
# 20/20 - 4s - loss: 0.5255 - acc: 0.8300 - val_loss: 0.5978 - val_acc: 0.8012 - 4s/epoch - 203ms/step
# Epoch 33/200
# 20/20 - 4s - loss: 0.4381 - acc: 0.8687 - val_loss: 0.5360 - val_acc: 0.8263 - 4s/epoch - 202ms/step
# Epoch 34/200
# 20/20 - 4s - loss: 0.4616 - acc: 0.8587 - val_loss: 0.5906 - val_acc: 0.8163 - 4s/epoch - 202ms/step
# Epoch 35/200
# 20/20 - 4s - loss: 0.4779 - acc: 0.8400 - val_loss: 0.6043 - val_acc: 0.7987 - 4s/epoch - 204ms/step
# Epoch 36/200
# 20/20 - 4s - loss: 0.4396 - acc: 0.8637 - val_loss: 0.5644 - val_acc: 0.8138 - 4s/epoch - 203ms/step
# Epoch 37/200
# 20/20 - 4s - loss: 0.4532 - acc: 0.8512 - val_loss: 0.5758 - val_acc: 0.8175 - 4s/epoch - 204ms/step
# Epoch 38/200
# 20/20 - 4s - loss: 0.3873 - acc: 0.8737 - val_loss: 0.5875 - val_acc: 0.8100 - 4s/epoch - 212ms/step
# Epoch 39/200
# 20/20 - 4s - loss: 0.4179 - acc: 0.8675 - val_loss: 0.5099 - val_acc: 0.8413 - 4s/epoch - 214ms/step
# Epoch 40/200
# 20/20 - 4s - loss: 0.4154 - acc: 0.8662 - val_loss: 0.5548 - val_acc: 0.8200 - 4s/epoch - 208ms/step
# Epoch 41/200
# 20/20 - 4s - loss: 0.3922 - acc: 0.8875 - val_loss: 0.5328 - val_acc: 0.8263 - 4s/epoch - 204ms/step
# Epoch 42/200
# 20/20 - 4s - loss: 0.3788 - acc: 0.8863 - val_loss: 0.5348 - val_acc: 0.8500 - 4s/epoch - 206ms/step
# Epoch 43/200
# 20/20 - 4s - loss: 0.4142 - acc: 0.8859 - val_loss: 0.5930 - val_acc: 0.8037 - 4s/epoch - 202ms/step
# Epoch 44/200
# 20/20 - 4s - loss: 0.3408 - acc: 0.8863 - val_loss: 0.5431 - val_acc: 0.8338 - 4s/epoch - 204ms/step
# Epoch 45/200
# 20/20 - 4s - loss: 0.3855 - acc: 0.8800 - val_loss: 0.5195 - val_acc: 0.8350 - 4s/epoch - 202ms/step
# Epoch 46/200
# 20/20 - 4s - loss: 0.3676 - acc: 0.8863 - val_loss: 0.4848 - val_acc: 0.8525 - 4s/epoch - 206ms/step
# Epoch 47/200
# 20/20 - 4s - loss: 0.3714 - acc: 0.8825 - val_loss: 0.4861 - val_acc: 0.8562 - 4s/epoch - 207ms/step
# Epoch 48/200
# 20/20 - 4s - loss: 0.3182 - acc: 0.8975 - val_loss: 0.4960 - val_acc: 0.8438 - 4s/epoch - 204ms/step
# Epoch 49/200
# 20/20 - 4s - loss: 0.2693 - acc: 0.9187 - val_loss: 0.5343 - val_acc: 0.8112 - 4s/epoch - 207ms/step
# Epoch 50/200
# 20/20 - 4s - loss: 0.3368 - acc: 0.8938 - val_loss: 0.4644 - val_acc: 0.8562 - 4s/epoch - 206ms/step
# Epoch 51/200
# 20/20 - 4s - loss: 0.2593 - acc: 0.9150 - val_loss: 0.5123 - val_acc: 0.8300 - 4s/epoch - 204ms/step
# Epoch 52/200
# 20/20 - 4s - loss: 0.2977 - acc: 0.9062 - val_loss: 0.5030 - val_acc: 0.8275 - 4s/epoch - 204ms/step
# Epoch 53/200
# 20/20 - 4s - loss: 0.2479 - acc: 0.9325 - val_loss: 0.4950 - val_acc: 0.8500 - 4s/epoch - 206ms/step
# Epoch 54/200
# 20/20 - 4s - loss: 0.2796 - acc: 0.9137 - val_loss: 0.3977 - val_acc: 0.8800 - 4s/epoch - 207ms/step
# Epoch 55/200
# 20/20 - 4s - loss: 0.2743 - acc: 0.9150 - val_loss: 0.4024 - val_acc: 0.8662 - 4s/epoch - 206ms/step
# Epoch 56/200
# 20/20 - 4s - loss: 0.2488 - acc: 0.9237 - val_loss: 0.4709 - val_acc: 0.8662 - 4s/epoch - 204ms/step
# Epoch 57/200
# 20/20 - 4s - loss: 0.2378 - acc: 0.9312 - val_loss: 0.4840 - val_acc: 0.8525 - 4s/epoch - 203ms/step
# Epoch 58/200
# 20/20 - 4s - loss: 0.2774 - acc: 0.9075 - val_loss: 0.5174 - val_acc: 0.8438 - 4s/epoch - 204ms/step
# Epoch 59/200
# 20/20 - 4s - loss: 0.2343 - acc: 0.9350 - val_loss: 0.4851 - val_acc: 0.8425 - 4s/epoch - 208ms/step
# Epoch 60/200
# 20/20 - 4s - loss: 0.2501 - acc: 0.9312 - val_loss: 0.4443 - val_acc: 0.8712 - 4s/epoch - 207ms/step
# Epoch 61/200
# 20/20 - 4s - loss: 0.2443 - acc: 0.9250 - val_loss: 0.4176 - val_acc: 0.8675 - 4s/epoch - 203ms/step
# Epoch 62/200
# 20/20 - 4s - loss: 0.2470 - acc: 0.9250 - val_loss: 0.4539 - val_acc: 0.8712 - 4s/epoch - 202ms/step
# Epoch 63/200
# 20/20 - 4s - loss: 0.2386 - acc: 0.9388 - val_loss: 0.4285 - val_acc: 0.8763 - 4s/epoch - 206ms/step
# Epoch 64/200
# 20/20 - 4s - loss: 0.2524 - acc: 0.9225 - val_loss: 0.4488 - val_acc: 0.8737 - 4s/epoch - 205ms/step

# %%
# summarize history for accuracy and loss
plt.figure(figsize=(6, 4))
plt.plot(history.history['acc'], "g--", label="Accuracy of training data")
plt.plot(history.history['val_acc'], "g", label="Accuracy of validation data")
plt.plot(history.history['loss'], "r--", label="Loss of training data")
plt.plot(history.history['val_loss'], "r", label="Loss of validation data")
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# %%
score = model.evaluate(test_generator, verbose=1)
print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 81/81 [==============================] - 5s 65ms/step - loss: 0.4161 - acc: 0.8710
#
# Accuracy on test data: 0.87
#
# Loss on test data: 0.42

# %%
y_pred_test = model.predict(test_generator)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = test_generator.classes
precision = precision_score(max_y_test, max_y_pred_test, average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(max_y_test, max_y_pred_test, average='weighted')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(max_y_test, max_y_pred_test, average='weighted')
print('F1 score: %f' % f1)
# Out:
# 81/81 [==============================] - 4s 39ms/step
# Precision: 0.870762
# Recall: 0.870958
# F1 score: 0.870119

# %%
LABELS = [0, 1, 2, 3, 4, 5, 6, 7]
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap="coolwarm",
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.show()

# %%
show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       658
#            1       0.87      0.90      0.88       641
#            2       0.88      0.88      0.88       563
#            3       0.87      0.83      0.85       251
#            4       0.84      0.79      0.82       243
#            5       0.80      0.81      0.81       220
#            6       0.82      0.68      0.75       219
#            7       0.97      0.97      0.97       421
#
#     accuracy                           0.87      3216
#    macro avg       0.86      0.85      0.85      3216
# weighted avg       0.87      0.87      0.87      3216

# %%
model.save("best_model_face_inception.h5")

# %% [markdown]
# ## Testing Results on Unseen Drivers
#
# ### Preparing Unseen Drivers Data
#
# We will now evaluate model performance on drivers it hasn't seen before. First, we prepare the data for evaluation.

# %%
UNSEEN_CLS = [os.path.join(os.getcwd(), UNSEEN_PATH, cls[0]) for cls in CLASS]
for cls_path in UNSEEN_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))

unseen_paths = []
for cls in range(NUM_CLASSES):
  for unseen_instance in os.listdir(UNSEEN_CLS[cls]):
    unseen_paths.append(os.path.join(UNSEEN_CLS[cls], unseen_instance))

unseen_classes = []
for cls in range(NUM_CLASSES):
  for unseen_instance in os.listdir(UNSEEN_CLS[cls]):
    unseen_classes.append(cls)

df_unseen = pd.DataFrame({'filename': unseen_paths, "class": unseen_classes})
df_unseen
# Out:
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c0
# 145
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c1
# 175
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c2
# 169
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c3
# 68
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c4
# 59
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c5
# 65
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c6
# 79
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\unseen\c7
# 80
#                                               filename  class
# 0    c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1    c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2    c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3    c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4    c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ..                                                 ...    ...
# 835  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 836  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 837  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 838  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 839  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [840 rows x 2 columns]

# %%
X_unseen = []
Y_unseen = []
for index, path in df_unseen.iterrows():
    if not (".DS_Store" in path[0]):
        img_orig = cv2.imread(path[0])
        frame = cv2.resize(img_orig, (640, 480))
        extracted_face = detectFaceOpenCVDnn(net, frame)
        if (index+1) % 135 == 0:
            print("Processed ", index + 1, "images. Continuing...")
        if len(extracted_face) > 0:
            X_unseen.append(np.asarray(extracted_face))
            Y_unseen.append(path[1])

print("Done!")
# Out:
# Processed  135 images. Continuing...
# Processed  270 images. Continuing...
# Processed  405 images. Continuing...
# Processed  540 images. Continuing...
# Processed  675 images. Continuing...
# Processed  810 images. Continuing...
# Done!

# %%
X_unseen_resized = []
Y_unseen_resized = []
i = 0
for x in X_unseen:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (75, 100))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        X_unseen_resized.append(img/255)
        Y_unseen_resized.append(Y_unseen[i])
    i+=1
X_unseen_resized = np.asarray(X_unseen_resized)
X_unseen_resized = X_unseen_resized.reshape(-1, 100, 75, 1)
X_unseen_resized.shape
# Out:
# (811, 100, 75, 1)

# %%
for i in range(X_unseen_resized.shape[0]):
    x_unseen = X_unseen_resized[i]*255
    if len(x_unseen)!=0 and len(x_unseen[0])!=0:   
        cv2.imwrite("Data/combined new faces/unseen/" + str(Y_unseen_resized[i]) + "/" + str(i) + ".jpg", x_unseen)

# %%
Y_unseen_cnn = np_utils.to_categorical(Y_unseen_resized, 8)
print('New y_test shape: ', Y_unseen_cnn.shape)
# Out:
# New y_test shape:  (811, 8)

# %%
model_cnn = keras.models.load_model('best_model_face_cnn.h5')
score = model_cnn.evaluate(X_unseen_resized, Y_unseen_cnn, verbose=1)

print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 26/26 [==============================] - 1s 17ms/step - loss: 2.1751 - accuracy: 0.2885
#
# Accuracy on test data: 0.29
#
# Loss on test data: 2.18

# %%
y_pred_test = model_cnn.predict(X_unseen_resized)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = Y_unseen_resized

show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 26/26 [==============================] - 0s 8ms/step
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.37      0.15      0.22       144
#            1       0.45      0.18      0.26       175
#            2       0.25      0.41      0.31       157
#            3       0.00      0.00      0.00        68
#            4       0.34      0.56      0.42        50
#            5       0.09      0.17      0.12        60
#            6       0.18      0.09      0.12        77
#            7       0.44      0.89      0.58        80
#
#     accuracy                           0.29       811
#    macro avg       0.26      0.31      0.25       811
# weighted avg       0.30      0.29      0.26       811

# %%
unseen_dir = "Data/combined new faces/unseen"
# Note that the test data should not be augmented!
unseen_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Flow training images in batches of 40 using train_datagen generator
unseen_generator = unseen_datagen.flow_from_directory(unseen_dir,
                                                    batch_size = 40,
                                                    class_mode = 'categorical', 
                                                    target_size = (100, 75), shuffle = False)
# Out:
# Found 811 images belonging to 8 classes.

# %%
model_inception = keras.models.load_model('best_model_face_inception.h5')
score = model_inception.evaluate(unseen_generator, verbose=1)

print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 21/21 [==============================] - 2s 56ms/step - loss: 1.5219 - acc: 0.5339
#
# Accuracy on test data: 0.53
#
# Loss on test data: 1.52

# %%
y_pred_test = model_inception.predict(unseen_generator)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = unseen_generator.classes

show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 21/21 [==============================] - 1s 37ms/step
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.68      0.62       144
#            1       0.77      0.33      0.46       175
#            2       0.64      0.57      0.60       157
#            3       0.20      0.37      0.26        68
#            4       0.59      0.60      0.59        50
#            5       0.42      0.57      0.49        60
#            6       0.38      0.40      0.39        77
#            7       0.77      0.86      0.81        80
#
#     accuracy                           0.53       811
#    macro avg       0.54      0.55      0.53       811
# weighted avg       0.59      0.53      0.54       811
