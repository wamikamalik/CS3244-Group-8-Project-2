# %% [markdown]
# # Extracting and Classifying Face Images
#
# https://dev.to/azure/opencv-detect-and-blur-faces-using-dnn-40ab
#
# https://towardsdatascience.com/face-detection-models-which-to-use-and-why-d263e82c302c

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import image
from sklearn.metrics import classification_report, get_scorer_names
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from mtcnn.mtcnn import MTCNN
from PIL import Image
from sklearn import metrics
import seaborn as sns

# We import the data set from tensorflow and build the model there
import tensorflow as tf
from tensorflow.keras import layers, models
from keras.utils import np_utils
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Import the inception model  
from tensorflow.keras.applications.inception_v3 import InceptionV3

import torch
# If you do not have a GPU or do not want to run this code on your GPU, comment out the following lines
torch.cuda.empty_cache()
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Extracting the Data
#
# The images stored in the combined dataset are extracted into separate train and test set paths.
#
# NOTE: Before running this file, please unzip the Distacted Driver Dataset that contains the combined dataset.

# %%
PARENT_PATH = os.getcwd()
DATA_PATH = os.path.join(os.getcwd(), "Combined New")
TEST_PATH = os.path.join(DATA_PATH, "test")
TRAIN_PATH = os.path.join(DATA_PATH, "train")
UNSEEN_PATH = os.path.join(DATA_PATH, "unseen")
NUM_CLASSES = 8
TRAIN_PATH
# Out:
# 'c:\\Users\\wamik\\Documents\\Notes Y4S2\\CS3244\\Projects\\Project 2\\CS3244-Group-8-Project-2\\Combined New\\train'

# %%
CLASS = [["c0", "Safe Driving"], ["c1", "Text"], ["c2", "Phone"], 
         ["c3", "Adjusting Radio"], ["c4", "Drinking"], 
         ["c5", "Reaching Behind"], ["c6", "Hair or Makeup"], 
         ["c7", "Talking to Passenger"]]
TEST_CLS = [os.path.join(os.getcwd(), TEST_PATH, cls[0]) for cls in CLASS]
TRAIN_CLS = [os.path.join(os.getcwd(), TRAIN_PATH, cls[0]) for cls in CLASS]
for cls_path in TEST_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
for cls_path in TRAIN_CLS:
  print(cls_path)
  print(len(os.listdir(cls_path)))
# Out:
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c0
# 711
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c1
# 667
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c2
# 602
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c3
# 264
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c4
# 255
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c5
# 243
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c6
# 242
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\test\c7
# 430
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c0
# 2131
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c1
# 2000
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c2
# 1805
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c3
# 791
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c4
# 762
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c5
# 726
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c6
# 723
# c:\Users\wamik\Documents\Notes Y4S2\CS3244\Projects\Project 2\CS3244-Group-8-Project-2\Combined New\train\c7
# 1287

# %% [markdown]
# For each class, the path of the training and test data is stored in separate lists. The corresponding labels are also stored in a different list

# %%
train_paths = []
test_paths = []
for cls in range(NUM_CLASSES):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    train_paths.append(os.path.join(TRAIN_CLS[cls], train_instance))
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_paths.append(os.path.join(TEST_CLS[cls], test_instance))

# %%
classes = []
test_classes = []
for cls in range(NUM_CLASSES):
  for train_instance in os.listdir(TRAIN_CLS[cls]):
    classes.append(cls)
  for test_instance in os.listdir(TEST_CLS[cls]):
    test_classes.append(cls)

# %% [markdown]
# Then separate dataframes storing the train and test paths with their corresponding labels are created.

# %%
df = pd.DataFrame({
  'filename': train_paths,
  'class': classes
})
df
# Out:
#                                                 filename  class
# 0      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4      c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                  ...    ...
# 10220  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10221  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10222  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10223  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 10224  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [10225 rows x 2 columns]

# %%
df_test = pd.DataFrame({
  'filename': test_paths,
  'class': test_classes
})
df_test
# Out:
#                                                filename  class
# 0     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 1     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 2     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 3     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# 4     c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      0
# ...                                                 ...    ...
# 3409  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3410  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3411  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3412  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
# 3413  c:\Users\wamik\Documents\Notes Y4S2\CS3244\Pro...      7
#
# [3414 rows x 2 columns]

# %%
# -----------------------------------------------
# Face Detection using DNN Net
# -----------------------------------------------
# detect faces using a DNN model 
# download model and prototxt from https://github.com/spmallick/learnopencv/tree/master/FaceDetectionComparison/models

def detectFaceOpenCVDnn(net, frame):
    
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]
    blob = cv2.dnn.blobFromImage(frame, 1.0, mean = [104, 117, 123])

    net.setInput(blob)
    detections = net.forward()
    conf_threshold = 0.1
    box = None
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            conf_threshold = confidence
            x1 = int(detections[0, 0, i, 3] * frameWidth)
            y1 = int(detections[0, 0, i, 4] * frameHeight)
            x2 = int(detections[0, 0, i, 5] * frameWidth)
            y2 = int(detections[0, 0, i, 6] * frameHeight)
            box = [x1, y1, x2, y2]

    if box == None:
        return []
    # extract the face
    face_boundary = frame[box[1]:box[3], box[0]:box[2]]

    # resize pixels to the model size
    # face_image = Image.fromarray(face_boundary)
    # face_array = np.asarray(face_image)

    return face_boundary

# %%
# load face detection model
modelFile = "models/res10_300x300_ssd_iter_140000_fp16.caffemodel"
configFile = "models/deploy.prototxt"
net = cv2.dnn.readNetFromCaffe(configFile, modelFile)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

img_orig = cv2.imread(df['filename'].iloc[10000])
plt.imshow(img_orig)
plt.show()
frame = cv2.resize(img_orig, (640, 480))

extracted_face = detectFaceOpenCVDnn(net, frame)
plt.imshow(extracted_face)
plt.show()

# %%
X_train_final = []
Y_train = []
for index, path in df.iterrows():
    img_orig = cv2.imread(path[0])
    frame = cv2.resize(img_orig, (640, 480))
    extracted_face = detectFaceOpenCVDnn(net, frame)
    if (index+1) % 135 == 0:
        print("Processed ", index + 1, "images. Continuing...")
    if len(extracted_face) > 0:
        X_train_final.append(np.asarray(extracted_face))
        Y_train.append(path[1])

print("Done!")
# Out:
# Processed  135 images. Continuing...
# Processed  270 images. Continuing...
# Processed  405 images. Continuing...
# Processed  540 images. Continuing...
# Processed  675 images. Continuing...
# Processed  810 images. Continuing...
# Processed  945 images. Continuing...
# Processed  1080 images. Continuing...
# Processed  1215 images. Continuing...
# Processed  1350 images. Continuing...
# Processed  1485 images. Continuing...
# Processed  1620 images. Continuing...
# Processed  1755 images. Continuing...
# Processed  1890 images. Continuing...
# Processed  2025 images. Continuing...
# Processed  2160 images. Continuing...
# Processed  2295 images. Continuing...
# Processed  2430 images. Continuing...
# Processed  2565 images. Continuing...
# Processed  2700 images. Continuing...
# Processed  2835 images. Continuing...
# Processed  2970 images. Continuing...
# Processed  3105 images. Continuing...
# Processed  3240 images. Continuing...
# Processed  3375 images. Continuing...
# Processed  3510 images. Continuing...
# Processed  3645 images. Continuing...
# Processed  3780 images. Continuing...
# Processed  3915 images. Continuing...
# Processed  4050 images. Continuing...
# Processed  4185 images. Continuing...
# Processed  4320 images. Continuing...
# Processed  4455 images. Continuing...
# Processed  4590 images. Continuing...
# Processed  4725 images. Continuing...
# Processed  4860 images. Continuing...
# Processed  4995 images. Continuing...
# Processed  5130 images. Continuing...
# Processed  5265 images. Continuing...
# Processed  5400 images. Continuing...
# Processed  5535 images. Continuing...
# Processed  5670 images. Continuing...
# Processed  5805 images. Continuing...
# Processed  5940 images. Continuing...
# Processed  6075 images. Continuing...
# Processed  6210 images. Continuing...
# Processed  6345 images. Continuing...
# Processed  6480 images. Continuing...
# Processed  6615 images. Continuing...
# Processed  6750 images. Continuing...
# Processed  6885 images. Continuing...
# Processed  7020 images. Continuing...
# Processed  7155 images. Continuing...
# Processed  7290 images. Continuing...
# Processed  7425 images. Continuing...
# Processed  7560 images. Continuing...
# Processed  7695 images. Continuing...
# Processed  7830 images. Continuing...
# Processed  7965 images. Continuing...
# Processed  8100 images. Continuing...
# Processed  8235 images. Continuing...
# Processed  8370 images. Continuing...
# Processed  8505 images. Continuing...
# Processed  8640 images. Continuing...
# Processed  8775 images. Continuing...
# Processed  8910 images. Continuing...
# Processed  9045 images. Continuing...
# Processed  9180 images. Continuing...
# Processed  9315 images. Continuing...
# Processed  9450 images. Continuing...
# Processed  9585 images. Continuing...
# Processed  9720 images. Continuing...
# Processed  9855 images. Continuing...
# Processed  9990 images. Continuing...
# Processed  10125 images. Continuing...
# Done!

# %%
print(len(X_train_final))
# Out:
# 9587

# %%
np.save("Data/combined new faces/processed_train_imgs.npy", X_train_final)
np.save("Data/combined new faces/train_labels.npy", Y_train)
# Out:
# c:\Users\wamik\miniconda3\lib\site-packages\numpy\lib\npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
X_test_final = []
Y_val = []
for index, path in df_test.iterrows():
    img_orig = cv2.imread(path[0])
    if img_orig is not None:
        frame = cv2.resize(img_orig, (640, 480))
        extracted_face = detectFaceOpenCVDnn(net, frame)
        if (index+1) % 135 == 0:
            print("Processed ", index + 1, "images. Continuing...")
        if len(extracted_face) > 0:
            X_test_final.append(np.asarray(extracted_face))
            Y_val.append(path[1])

print("Done!")
# Out:
# Processed  135 images. Continuing...
# Processed  270 images. Continuing...
# Processed  405 images. Continuing...
# Processed  540 images. Continuing...
# Processed  675 images. Continuing...
# Processed  810 images. Continuing...
# Processed  945 images. Continuing...
# Processed  1080 images. Continuing...
# Processed  1215 images. Continuing...
# Processed  1350 images. Continuing...
# Processed  1485 images. Continuing...
# Processed  1620 images. Continuing...
# Processed  1755 images. Continuing...
# Processed  1890 images. Continuing...
# Processed  2025 images. Continuing...
# Processed  2160 images. Continuing...
# Processed  2295 images. Continuing...
# Processed  2430 images. Continuing...
# Processed  2565 images. Continuing...
# Processed  2700 images. Continuing...
# Processed  2835 images. Continuing...
# Processed  2970 images. Continuing...
# Processed  3105 images. Continuing...
# Processed  3240 images. Continuing...
# Processed  3375 images. Continuing...
# Done!

# %%
print(len(X_test_final))
# Out:
# 3225

# %%
np.save("Data/combined new faces/processed_test_data.npy", X_test_final)
np.save("Data/combined new faces/test_labels.npy", Y_val)
# Out:
# c:\Users\wamik\miniconda3\lib\site-packages\numpy\lib\npyio.py:521: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %% [markdown]
# ## Loading Faces Train data

# %%
X_train = np.load("Data/combined new faces/processed_train_imgs.npy", allow_pickle=True)
Y_train = np.load("Data/combined new faces/train_labels.npy")

# %%
X_test = np.load("Data/combined new faces/processed_test_data.npy", allow_pickle=True)
Y_test = np.load("Data/combined new faces/test_labels.npy")

# %%
X_train_resized = []
Y_train_resized = []
i = 0
for x in X_train:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (75, 100))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        # img_blur = cv2.GaussianBlur(img, (3,3), 0)
        # edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
        # edges = np.asarray(edges)
        # edges = edges.reshape(120, 80, 1)
        X_train_resized.append(img/255.0)
        Y_train_resized.append(Y_train[i])
    i+=1
X_train_resized = np.asarray(X_train_resized)
X_train_resized = X_train_resized.reshape(-1, 100, 75, 1)
X_train_resized.shape
# Out:
# (9564, 100, 75, 1)

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=Y_train_resized, bins='auto', color='#0504aa')
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Labels')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# counts = []
# for i in range(0, 8):
#     counts.append(Y_train_resized.count(i))
# np.argmin(counts)

# %%
# df_resized_train = pd.DataFrame({"img": range(11797), "class": Y_train_resized})
# df_resized_train

# %%
# from sklearn.utils import resample
# X_train_sampled = []
# Y_train_sampled = []
# for c in range(0, 8):
#     to_sample = df_resized_train[df_resized_train['class'] == c]
#     downsample = resample(to_sample,
#              replace=True,
#              n_samples=counts[5],
#              random_state=42)
#     for index, val in downsample['img'].items():
#         X_train_sampled.append(X_train_resized[val])
#         Y_train_sampled.append(c)
# X_train_sampled = np.asarray(X_train_sampled)
# X_train_sampled.shape

# %%
(X_train, X_val, Y_train, Y_val) = train_test_split(X_train_resized, Y_train_resized, test_size=0.2, stratify=Y_train_resized, random_state=42)
X_train = np.asarray(X_train)
Y_train = np.asarray(Y_train)
X_val = np.asarray(X_val)
Y_val = np.asarray(Y_val)
print(X_val.shape)
print(Y_val.shape)
# Out:
# (1913, 100, 75, 1)
# (1913,)

# %%
Y_train_resized = np_utils.to_categorical(Y_train, 8)
print('New y_train shape: ', Y_train_resized.shape)
Y_val_resized = np_utils.to_categorical(Y_val, 8)
print('New y_val shape: ', Y_val_resized.shape)
# Out:
# New y_train shape:  (7651, 8)
# New y_val shape:  (1913, 8)

# %%
X_test_resized = []
Y_test_resized = []
i = 0
for x in X_test:
    if len(x)!=0 and len(x[0])!=0:
        img = cv2.resize(x, (75, 100))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        # img_blur = cv2.GaussianBlur(img, (3,3), 0)
        # edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
        # edges = np.asarray(edges)
        # edges = edges.reshape(120, 80, 1)
        X_test_resized.append(img/255)
        Y_test_resized.append(Y_test[i])
    i+=1
X_test_resized = np.asarray(X_test_resized)
X_test_resized = X_test_resized.reshape(-1, 100, 75, 1)
X_test_resized.shape
# Out:
# (3216, 100, 75, 1)

# %%
Y_test_resized = np_utils.to_categorical(Y_test_resized, 8)
print('New y_test shape: ', Y_test_resized.shape)
# Out:
# New y_test shape:  (3216, 8)

# %%
model = models.Sequential()
model.add(layers.Conv2D(16, (2, 2), activation='relu', input_shape=(100, 75, 1)))
# model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((3, 3)))
model.add(layers.Conv2D(32, (2, 2), activation='relu'))
# model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((4, 4)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_386 (Conv2D)         (None, 99, 74, 16)        80
#
#  max_pooling2d_26 (MaxPoolin  (None, 33, 24, 16)       0
#  g2D)
#
#  conv2d_387 (Conv2D)         (None, 32, 23, 32)        2080
#
#  max_pooling2d_27 (MaxPoolin  (None, 8, 5, 32)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 1280)              0
#
#  dropout_9 (Dropout)         (None, 1280)              0
#
#  dense_16 (Dense)            (None, 64)                81984
#
#  dense_17 (Dense)            (None, 8)                 520
#
# =================================================================
# Total params: 84,664
# Trainable params: 84,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor='accuracy', patience=5)
]

opt = keras.optimizers.SGD(learning_rate=0.01)

model.compile(loss='categorical_crossentropy',
                optimizer=opt, metrics=['accuracy'])

BATCH_SIZE = 30
EPOCHS = 100

history = model.fit(X_train, Y_train_resized, epochs=EPOCHS, batch_size=BATCH_SIZE,callbacks=callbacks_list,
                    validation_data=(X_val, Y_val_resized))
# Out:
# Epoch 1/100
# 256/256 [==============================] - 9s 31ms/step - loss: 2.0171 - accuracy: 0.1944 - val_loss: 1.9660 - val_accuracy: 0.2211
# Epoch 2/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.9657 - accuracy: 0.2155 - val_loss: 1.9500 - val_accuracy: 0.2420
# Epoch 3/100
# 256/256 [==============================] - 8s 32ms/step - loss: 1.9494 - accuracy: 0.2357 - val_loss: 1.9284 - val_accuracy: 0.2462
# Epoch 4/100
# 256/256 [==============================] - 8s 31ms/step - loss: 1.9167 - accuracy: 0.2605 - val_loss: 1.8876 - val_accuracy: 0.2546
# Epoch 5/100
# 256/256 [==============================] - 8s 33ms/step - loss: 1.8808 - accuracy: 0.2849 - val_loss: 1.8553 - val_accuracy: 0.2948
# Epoch 6/100
# 256/256 [==============================] - 8s 31ms/step - loss: 1.8507 - accuracy: 0.2987 - val_loss: 1.8167 - val_accuracy: 0.3042
# Epoch 7/100
# 256/256 [==============================] - 8s 32ms/step - loss: 1.8224 - accuracy: 0.3162 - val_loss: 1.8066 - val_accuracy: 0.2859
# Epoch 8/100
# 256/256 [==============================] - 8s 31ms/step - loss: 1.8035 - accuracy: 0.3126 - val_loss: 1.7672 - val_accuracy: 0.3570
# Epoch 9/100
# 256/256 [==============================] - 8s 30ms/step - loss: 1.7787 - accuracy: 0.3342 - val_loss: 1.7438 - val_accuracy: 0.3570
# Epoch 10/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.7721 - accuracy: 0.3351 - val_loss: 1.7605 - val_accuracy: 0.3236
# Epoch 11/100
# 256/256 [==============================] - 8s 30ms/step - loss: 1.7500 - accuracy: 0.3432 - val_loss: 1.7186 - val_accuracy: 0.3398
# Epoch 12/100
# 256/256 [==============================] - 8s 31ms/step - loss: 1.7399 - accuracy: 0.3535 - val_loss: 1.7064 - val_accuracy: 0.3769
# Epoch 13/100
# 256/256 [==============================] - 8s 31ms/step - loss: 1.7288 - accuracy: 0.3564 - val_loss: 1.7256 - val_accuracy: 0.3173
# Epoch 14/100
# 256/256 [==============================] - 8s 33ms/step - loss: 1.7185 - accuracy: 0.3558 - val_loss: 1.6698 - val_accuracy: 0.4072
# Epoch 15/100
# 256/256 [==============================] - 8s 32ms/step - loss: 1.7050 - accuracy: 0.3654 - val_loss: 1.6576 - val_accuracy: 0.4020
# Epoch 16/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.6877 - accuracy: 0.3743 - val_loss: 1.6480 - val_accuracy: 0.3999
# Epoch 17/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.6858 - accuracy: 0.3704 - val_loss: 1.6516 - val_accuracy: 0.4203
# Epoch 18/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.6701 - accuracy: 0.3849 - val_loss: 1.6820 - val_accuracy: 0.3330
# Epoch 19/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.6501 - accuracy: 0.3926 - val_loss: 1.6825 - val_accuracy: 0.3795
# Epoch 20/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.6354 - accuracy: 0.4040 - val_loss: 1.6158 - val_accuracy: 0.4041
# Epoch 21/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.6297 - accuracy: 0.4047 - val_loss: 1.6176 - val_accuracy: 0.4145
# Epoch 22/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.6141 - accuracy: 0.4111 - val_loss: 1.6199 - val_accuracy: 0.3748
# Epoch 23/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.5897 - accuracy: 0.4201 - val_loss: 1.5437 - val_accuracy: 0.4590
# Epoch 24/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.5790 - accuracy: 0.4260 - val_loss: 1.5585 - val_accuracy: 0.4349
# Epoch 25/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.5617 - accuracy: 0.4318 - val_loss: 1.7729 - val_accuracy: 0.3722
# Epoch 26/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.5420 - accuracy: 0.4418 - val_loss: 1.5285 - val_accuracy: 0.4433
# Epoch 27/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.5247 - accuracy: 0.4414 - val_loss: 1.5641 - val_accuracy: 0.3863
# Epoch 28/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.5062 - accuracy: 0.4537 - val_loss: 1.4899 - val_accuracy: 0.4543
# Epoch 29/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.4900 - accuracy: 0.4618 - val_loss: 1.4589 - val_accuracy: 0.4642
# Epoch 30/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.4742 - accuracy: 0.4687 - val_loss: 1.4533 - val_accuracy: 0.4527
# Epoch 31/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.4590 - accuracy: 0.4697 - val_loss: 1.4052 - val_accuracy: 0.5024
# Epoch 32/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.4386 - accuracy: 0.4837 - val_loss: 1.3943 - val_accuracy: 0.5018
# Epoch 33/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.4290 - accuracy: 0.4861 - val_loss: 1.4428 - val_accuracy: 0.4778
# Epoch 34/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.4130 - accuracy: 0.4878 - val_loss: 1.5541 - val_accuracy: 0.4422
# Epoch 35/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.4037 - accuracy: 0.4988 - val_loss: 1.3896 - val_accuracy: 0.4924
# Epoch 36/100
# 256/256 [==============================] - 8s 29ms/step - loss: 1.3872 - accuracy: 0.5022 - val_loss: 1.3390 - val_accuracy: 0.5034
# Epoch 37/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.3772 - accuracy: 0.4998 - val_loss: 1.4110 - val_accuracy: 0.4642
# Epoch 38/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.3614 - accuracy: 0.5133 - val_loss: 1.5983 - val_accuracy: 0.3952
# Epoch 39/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.3584 - accuracy: 0.5080 - val_loss: 1.4199 - val_accuracy: 0.5013
# Epoch 40/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.3375 - accuracy: 0.5203 - val_loss: 1.2858 - val_accuracy: 0.5395
# Epoch 41/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.3349 - accuracy: 0.5282 - val_loss: 1.2530 - val_accuracy: 0.5588
# Epoch 42/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.3129 - accuracy: 0.5278 - val_loss: 1.4396 - val_accuracy: 0.4360
# Epoch 43/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.3092 - accuracy: 0.5347 - val_loss: 1.2818 - val_accuracy: 0.5159
# Epoch 44/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2877 - accuracy: 0.5422 - val_loss: 1.2191 - val_accuracy: 0.5865
# Epoch 45/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2772 - accuracy: 0.5526 - val_loss: 1.2722 - val_accuracy: 0.5280
# Epoch 46/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2799 - accuracy: 0.5418 - val_loss: 1.3338 - val_accuracy: 0.5217
# Epoch 47/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2632 - accuracy: 0.5565 - val_loss: 1.2046 - val_accuracy: 0.5923
# Epoch 48/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2488 - accuracy: 0.5577 - val_loss: 1.1724 - val_accuracy: 0.5938
# Epoch 49/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2437 - accuracy: 0.5631 - val_loss: 1.1996 - val_accuracy: 0.5646
# Epoch 50/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2291 - accuracy: 0.5670 - val_loss: 1.1512 - val_accuracy: 0.5991
# Epoch 51/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2309 - accuracy: 0.5669 - val_loss: 2.2599 - val_accuracy: 0.3393
# Epoch 52/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2229 - accuracy: 0.5680 - val_loss: 1.3573 - val_accuracy: 0.5238
# Epoch 53/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.2090 - accuracy: 0.5752 - val_loss: 1.2447 - val_accuracy: 0.5781
# Epoch 54/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.1988 - accuracy: 0.5797 - val_loss: 1.1293 - val_accuracy: 0.6095
# Epoch 55/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.1803 - accuracy: 0.5815 - val_loss: 1.2624 - val_accuracy: 0.5332
# Epoch 56/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.1741 - accuracy: 0.5850 - val_loss: 1.1714 - val_accuracy: 0.5881
# Epoch 57/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.1722 - accuracy: 0.5874 - val_loss: 1.2518 - val_accuracy: 0.5468
# Epoch 58/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.1637 - accuracy: 0.5892 - val_loss: 1.5371 - val_accuracy: 0.4835
# Epoch 59/100
# 256/256 [==============================] - 8s 31ms/step - loss: 1.1627 - accuracy: 0.5909 - val_loss: 2.2757 - val_accuracy: 0.3555
# Epoch 60/100
# 256/256 [==============================] - 8s 32ms/step - loss: 1.1562 - accuracy: 0.5930 - val_loss: 1.2996 - val_accuracy: 0.5222
# Epoch 61/100
# 256/256 [==============================] - 8s 31ms/step - loss: 1.1316 - accuracy: 0.6001 - val_loss: 1.2404 - val_accuracy: 0.5546
# Epoch 62/100
# 256/256 [==============================] - 8s 32ms/step - loss: 1.1203 - accuracy: 0.6078 - val_loss: 1.1660 - val_accuracy: 0.5823
# Epoch 63/100
# 256/256 [==============================] - 7s 29ms/step - loss: 1.1079 - accuracy: 0.6148 - val_loss: 1.0807 - val_accuracy: 0.6309
# Epoch 64/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.1041 - accuracy: 0.6140 - val_loss: 1.0542 - val_accuracy: 0.6529
# Epoch 65/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0870 - accuracy: 0.6279 - val_loss: 1.2827 - val_accuracy: 0.5614
# Epoch 66/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0730 - accuracy: 0.6263 - val_loss: 1.0631 - val_accuracy: 0.6393
# Epoch 67/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0848 - accuracy: 0.6246 - val_loss: 1.0435 - val_accuracy: 0.6482
# Epoch 68/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0873 - accuracy: 0.6212 - val_loss: 1.1502 - val_accuracy: 0.5818
# Epoch 69/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0652 - accuracy: 0.6280 - val_loss: 1.0150 - val_accuracy: 0.6555
# Epoch 70/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0529 - accuracy: 0.6314 - val_loss: 1.2199 - val_accuracy: 0.5635
# Epoch 71/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0449 - accuracy: 0.6360 - val_loss: 0.9917 - val_accuracy: 0.6691
# Epoch 72/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0398 - accuracy: 0.6373 - val_loss: 1.4026 - val_accuracy: 0.5112
# Epoch 73/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0402 - accuracy: 0.6440 - val_loss: 0.9935 - val_accuracy: 0.6660
# Epoch 74/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0259 - accuracy: 0.6381 - val_loss: 1.5191 - val_accuracy: 0.4611
# Epoch 75/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0268 - accuracy: 0.6482 - val_loss: 0.9791 - val_accuracy: 0.6837
# Epoch 76/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0004 - accuracy: 0.6536 - val_loss: 0.9957 - val_accuracy: 0.6560
# Epoch 77/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0067 - accuracy: 0.6502 - val_loss: 1.0504 - val_accuracy: 0.6409
# Epoch 78/100
# 256/256 [==============================] - 7s 28ms/step - loss: 1.0060 - accuracy: 0.6552 - val_loss: 1.2297 - val_accuracy: 0.5740
# Epoch 79/100
# 256/256 [==============================] - 7s 28ms/step - loss: 0.9916 - accuracy: 0.6598 - val_loss: 1.0942 - val_accuracy: 0.6147
# Epoch 80/100
# 256/256 [==============================] - 7s 28ms/step - loss: 0.9804 - accuracy: 0.6591 - val_loss: 0.9994 - val_accuracy: 0.6607
# Epoch 81/100
# 256/256 [==============================] - 7s 29ms/step - loss: 0.9792 - accuracy: 0.6631 - val_loss: 0.9443 - val_accuracy: 0.6869
# Epoch 82/100
# 256/256 [==============================] - 7s 28ms/step - loss: 0.9717 - accuracy: 0.6646 - val_loss: 0.9635 - val_accuracy: 0.6743
# Epoch 83/100
# 256/256 [==============================] - 8s 32ms/step - loss: 0.9661 - accuracy: 0.6645 - val_loss: 0.9815 - val_accuracy: 0.6665
# Epoch 84/100
# 256/256 [==============================] - 8s 32ms/step - loss: 0.9544 - accuracy: 0.6749 - val_loss: 0.9622 - val_accuracy: 0.6817
# Epoch 85/100
# 256/256 [==============================] - 8s 33ms/step - loss: 0.9342 - accuracy: 0.6766 - val_loss: 0.9160 - val_accuracy: 0.7073
# Epoch 86/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.9382 - accuracy: 0.6773 - val_loss: 0.9325 - val_accuracy: 0.6999
# Epoch 87/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.9363 - accuracy: 0.6790 - val_loss: 0.9461 - val_accuracy: 0.6890
# Epoch 88/100
# 256/256 [==============================] - 8s 32ms/step - loss: 0.9330 - accuracy: 0.6803 - val_loss: 0.9263 - val_accuracy: 0.6884
# Epoch 89/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.9355 - accuracy: 0.6763 - val_loss: 1.2324 - val_accuracy: 0.5588
# Epoch 90/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.9161 - accuracy: 0.6810 - val_loss: 1.9942 - val_accuracy: 0.4731
# Epoch 91/100
# 256/256 [==============================] - 8s 32ms/step - loss: 0.9387 - accuracy: 0.6783 - val_loss: 1.2188 - val_accuracy: 0.5834
# Epoch 92/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.9078 - accuracy: 0.6921 - val_loss: 1.3347 - val_accuracy: 0.5682
# Epoch 93/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.9124 - accuracy: 0.6824 - val_loss: 0.8959 - val_accuracy: 0.7067
# Epoch 94/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.8919 - accuracy: 0.6931 - val_loss: 0.8812 - val_accuracy: 0.7099
# Epoch 95/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.8884 - accuracy: 0.6977 - val_loss: 1.3068 - val_accuracy: 0.6158
# Epoch 96/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.8923 - accuracy: 0.6968 - val_loss: 0.8811 - val_accuracy: 0.7130
# Epoch 97/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.8612 - accuracy: 0.7000 - val_loss: 0.8569 - val_accuracy: 0.7224
# Epoch 98/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.8746 - accuracy: 0.7013 - val_loss: 0.8594 - val_accuracy: 0.7214
# Epoch 99/100
# 256/256 [==============================] - 8s 31ms/step - loss: 0.8537 - accuracy: 0.7106 - val_loss: 0.8858 - val_accuracy: 0.7125
# Epoch 100/100
# 256/256 [==============================] - 8s 32ms/step - loss: 0.8468 - accuracy: 0.7037 - val_loss: 0.9298 - val_accuracy: 0.7083

# %%
# summarize history for accuracy and loss
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], "g--", label="Accuracy of training data")
plt.plot(history.history['val_accuracy'], "g", label="Accuracy of validation data")
plt.plot(history.history['loss'], "r--", label="Loss of training data")
plt.plot(history.history['val_loss'], "r", label="Loss of validation data")
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# %%
score = model.evaluate(X_test_resized, Y_test_resized, verbose=1)

print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 101/101 [==============================] - 2s 16ms/step - loss: 0.9578 - accuracy: 0.6919
#
# Accuracy on test data: 0.69
#
# Loss on test data: 0.96

# %%
LABELS = [0, 1, 2, 3, 4, 5, 6, 7]
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap="coolwarm",
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.show()

# %%
y_pred_test = model.predict(X_test_resized)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = np.argmax(Y_test_resized, axis=1)

show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 101/101 [==============================] - 1s 12ms/step
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.73       658
#            1       0.66      0.77      0.71       641
#            2       0.75      0.70      0.73       563
#            3       0.63      0.62      0.62       251
#            4       0.75      0.59      0.66       243
#            5       0.67      0.29      0.40       220
#            6       0.61      0.34      0.44       219
#            7       0.68      0.98      0.81       421
#
#     accuracy                           0.69      3216
#    macro avg       0.68      0.63      0.64      3216
# weighted avg       0.69      0.69      0.68      3216

# %%
model.save("best_model_face_cnn.h5")

# %% [markdown]
# ## Preparing Data For Transfer Learning
# ### Saving Data As Images

# %%
for i in range(X_train.shape[0]):
    x = X_train[i]*255
    if len(x)!=0 and len(x[0])!=0:   
        cv2.imwrite("Data/combined new faces/train/" + str(Y_train[i]) + "/" + str(i) + ".jpg", x)

# %%
for i in range(X_val.shape[0]):
    x_val = X_val[i]*255
    if len(x_val)!=0 and len(x_val[0])!=0:   
        cv2.imwrite("Data/combined new faces/val/" + str(Y_val[i]) + "/" + str(i) + ".jpg", x_val)

# %%
Y_test = [np.argmax(y, axis=None, out=None) for y in Y_test_resized]
for i in range(X_test_resized.shape[0]):
    x_test = X_test_resized[i]*255
    if len(x_test)!=0 and len(x_test[0])!=0:   
        cv2.imwrite("Data/combined new faces/test/" + str(Y_test[i]) + "/" + str(i) + ".jpg", x_test)

# %% [markdown]
# ## Transfer Learning with TensorFlow Keras
#
# https://github.com/tejanirla/image_classification/blob/master/transfer_learning.ipynb

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_dir = "Data/combined new faces/train"
val_dir = "Data/combined new faces/val"
test_dir = "Data/combined new faces/test"
# Add our data-augmentation parameters to ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255.,
                                   width_shift_range = 0.02,
                                   height_shift_range = 0.02,
                                   horizontal_flip = False)

# Note that the validation data should not be augmented!
val_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Note that the test data should not be augmented!
test_datagen = ImageDataGenerator( rescale = 1.0/255. )

# Flow training images in batches of 40 using train_datagen generator
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size = 40,
                                                    class_mode = 'categorical', 
                                                    target_size = (100, 75), shuffle = True)   
# Flow validation images in batches of 40 using val_datagen generator
val_generator =  val_datagen.flow_from_directory( val_dir,
                                                          batch_size  = 40,
                                                          class_mode  = 'categorical', 
                                                          target_size = (100, 75), shuffle = True)  

# Flow validation images in batches of 40 using test_datagen generator
test_generator =  test_datagen.flow_from_directory( test_dir,
                                                          batch_size  = 40,
                                                          class_mode  = 'categorical', 
                                                          target_size = (100, 75), shuffle = False)
# Out:
# Found 7651 images belonging to 8 classes.
# Found 1913 images belonging to 8 classes.
# Found 3216 images belonging to 8 classes.

# %%
pre_trained_model = InceptionV3(input_shape = (100, 75, 3), # Shape of our images
                                include_top = False, # Leave out the last fully connected layer
                                weights = 'imagenet')
for layer in pre_trained_model.layers:
    layer.trainable = True

# %% [markdown]
# https://github.com/tejanirla/image_classification/blob/master/transfer_learning.ipynb

# %%
last_layer = pre_trained_model.get_layer('mixed4') #Only use layers including and above 'mixed4'
last_op = last_layer.output
# Flatten the output layer to 1 dimension
x = layers.Flatten()(last_op)
# # Add a fully connected layer with 1,024 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)                  
# Add a final sigmoid layer for classification
x = layers.Dense  (8, activation='softmax')(x)           

model = keras.Model(pre_trained_model.input, x) 

model.compile(optimizer = keras.optimizers.SGD(learning_rate=0.01), 
              loss = 'categorical_crossentropy', 
              metrics = ['acc'])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('acc')>0.95):
      print("\nReached 95% accuracy so cancelling training!")
      self.model.stop_training = True

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(monitor='acc', patience=2)
]

callbacks = myCallback()
history = model.fit(
            train_generator,
            validation_data = val_generator,
            steps_per_epoch = 20,
            epochs = 100,
            validation_steps = 20,
            verbose = 2,
            callbacks=callbacks)
# Out:
# Epoch 1/100
# 20/20 - 13s - loss: 2.0323 - acc: 0.2713 - val_loss: 1.7052 - val_acc: 0.3388 - 13s/epoch - 649ms/step
# Epoch 2/100
# 20/20 - 9s - loss: 1.5762 - acc: 0.4112 - val_loss: 1.4520 - val_acc: 0.4550 - 9s/epoch - 470ms/step
# Epoch 3/100
# 20/20 - 9s - loss: 1.4832 - acc: 0.4682 - val_loss: 1.3824 - val_acc: 0.5300 - 9s/epoch - 466ms/step
# Epoch 4/100
# 20/20 - 9s - loss: 1.3622 - acc: 0.5275 - val_loss: 1.3191 - val_acc: 0.5375 - 9s/epoch - 468ms/step
# Epoch 5/100
# 20/20 - 9s - loss: 1.2635 - acc: 0.5750 - val_loss: 1.2352 - val_acc: 0.5700 - 9s/epoch - 464ms/step
# Epoch 6/100
# 20/20 - 9s - loss: 1.1558 - acc: 0.6087 - val_loss: 1.1750 - val_acc: 0.6012 - 9s/epoch - 462ms/step
# Epoch 7/100
# 20/20 - 9s - loss: 1.1637 - acc: 0.5913 - val_loss: 1.1714 - val_acc: 0.5987 - 9s/epoch - 463ms/step
# Epoch 8/100
# 20/20 - 9s - loss: 1.0629 - acc: 0.6363 - val_loss: 1.1047 - val_acc: 0.6300 - 9s/epoch - 463ms/step
# Epoch 9/100
# 20/20 - 9s - loss: 1.0424 - acc: 0.6500 - val_loss: 1.0659 - val_acc: 0.6587 - 9s/epoch - 463ms/step
# Epoch 10/100
# 20/20 - 9s - loss: 0.9691 - acc: 0.6762 - val_loss: 1.0755 - val_acc: 0.6650 - 9s/epoch - 462ms/step
# Epoch 11/100
# 20/20 - 9s - loss: 0.9965 - acc: 0.6675 - val_loss: 0.9529 - val_acc: 0.6988 - 9s/epoch - 463ms/step
# Epoch 12/100
# 20/20 - 9s - loss: 0.8907 - acc: 0.7088 - val_loss: 0.9599 - val_acc: 0.6712 - 9s/epoch - 462ms/step
# Epoch 13/100
# 20/20 - 9s - loss: 0.8631 - acc: 0.7063 - val_loss: 0.8887 - val_acc: 0.7125 - 9s/epoch - 463ms/step
# Epoch 14/100
# 20/20 - 9s - loss: 0.8358 - acc: 0.7250 - val_loss: 0.9321 - val_acc: 0.6925 - 9s/epoch - 463ms/step
# Epoch 15/100
# 20/20 - 9s - loss: 0.8298 - acc: 0.7188 - val_loss: 0.8257 - val_acc: 0.7400 - 9s/epoch - 463ms/step
# Epoch 16/100
# 20/20 - 9s - loss: 0.8586 - acc: 0.7113 - val_loss: 0.8375 - val_acc: 0.7325 - 9s/epoch - 463ms/step
# Epoch 17/100
# 20/20 - 9s - loss: 0.7408 - acc: 0.7462 - val_loss: 0.7998 - val_acc: 0.7462 - 9s/epoch - 461ms/step
# Epoch 18/100
# 20/20 - 9s - loss: 0.6759 - acc: 0.7962 - val_loss: 0.7249 - val_acc: 0.7538 - 9s/epoch - 461ms/step
# Epoch 19/100
# 20/20 - 9s - loss: 0.7262 - acc: 0.7613 - val_loss: 0.7562 - val_acc: 0.7700 - 9s/epoch - 461ms/step
# Epoch 20/100
# 20/20 - 9s - loss: 0.7452 - acc: 0.7538 - val_loss: 0.6893 - val_acc: 0.7775 - 9s/epoch - 462ms/step
# Epoch 21/100
# 20/20 - 9s - loss: 0.6746 - acc: 0.7925 - val_loss: 0.6990 - val_acc: 0.7675 - 9s/epoch - 451ms/step
# Epoch 22/100
# 20/20 - 9s - loss: 0.6243 - acc: 0.8050 - val_loss: 0.6638 - val_acc: 0.7812 - 9s/epoch - 462ms/step
# Epoch 23/100
# 20/20 - 9s - loss: 0.6621 - acc: 0.7638 - val_loss: 0.7158 - val_acc: 0.7788 - 9s/epoch - 462ms/step
# Epoch 24/100
# 20/20 - 9s - loss: 0.6369 - acc: 0.7825 - val_loss: 0.6730 - val_acc: 0.7750 - 9s/epoch - 461ms/step
# Epoch 25/100
# 20/20 - 9s - loss: 0.5780 - acc: 0.8138 - val_loss: 0.6785 - val_acc: 0.7738 - 9s/epoch - 471ms/step
# Epoch 26/100
# 20/20 - 9s - loss: 0.5516 - acc: 0.8418 - val_loss: 0.7171 - val_acc: 0.7675 - 9s/epoch - 467ms/step
# Epoch 27/100
# 20/20 - 9s - loss: 0.5506 - acc: 0.8225 - val_loss: 0.6209 - val_acc: 0.8025 - 9s/epoch - 470ms/step
# Epoch 28/100
# 20/20 - 9s - loss: 0.5494 - acc: 0.8350 - val_loss: 0.6758 - val_acc: 0.7788 - 9s/epoch - 466ms/step
# Epoch 29/100
# 20/20 - 9s - loss: 0.5230 - acc: 0.8375 - val_loss: 0.6149 - val_acc: 0.7975 - 9s/epoch - 464ms/step
# Epoch 30/100
# 20/20 - 9s - loss: 0.5552 - acc: 0.8200 - val_loss: 0.6351 - val_acc: 0.7937 - 9s/epoch - 463ms/step
# Epoch 31/100
# 20/20 - 9s - loss: 0.5188 - acc: 0.8325 - val_loss: 0.5967 - val_acc: 0.8075 - 9s/epoch - 465ms/step
# Epoch 32/100
# 20/20 - 9s - loss: 0.4752 - acc: 0.8512 - val_loss: 0.6493 - val_acc: 0.8050 - 9s/epoch - 463ms/step
# Epoch 33/100
# 20/20 - 9s - loss: 0.5083 - acc: 0.8462 - val_loss: 0.5824 - val_acc: 0.8062 - 9s/epoch - 462ms/step
# Epoch 34/100
# 20/20 - 9s - loss: 0.4793 - acc: 0.8534 - val_loss: 0.5503 - val_acc: 0.8238 - 9s/epoch - 453ms/step
# Epoch 35/100
# 20/20 - 9s - loss: 0.4060 - acc: 0.8687 - val_loss: 0.5505 - val_acc: 0.8175 - 9s/epoch - 462ms/step
# Epoch 36/100
# 20/20 - 9s - loss: 0.4347 - acc: 0.8475 - val_loss: 0.5799 - val_acc: 0.8163 - 9s/epoch - 461ms/step
# Epoch 37/100
# 20/20 - 9s - loss: 0.4644 - acc: 0.8462 - val_loss: 0.5120 - val_acc: 0.8450 - 9s/epoch - 461ms/step
# Epoch 38/100
# 20/20 - 9s - loss: 0.3735 - acc: 0.8888 - val_loss: 0.5332 - val_acc: 0.8300 - 9s/epoch - 464ms/step
# Epoch 39/100
# 20/20 - 9s - loss: 0.3983 - acc: 0.8838 - val_loss: 0.5311 - val_acc: 0.8275 - 9s/epoch - 462ms/step
# Epoch 40/100
# 20/20 - 9s - loss: 0.4370 - acc: 0.8600 - val_loss: 0.5449 - val_acc: 0.8363 - 9s/epoch - 462ms/step
# Epoch 41/100
# 20/20 - 9s - loss: 0.3927 - acc: 0.8763 - val_loss: 0.4988 - val_acc: 0.8388 - 9s/epoch - 463ms/step
# Epoch 42/100
# 20/20 - 9s - loss: 0.3544 - acc: 0.8898 - val_loss: 0.4992 - val_acc: 0.8425 - 9s/epoch - 453ms/step
# Epoch 43/100
# 20/20 - 9s - loss: 0.3880 - acc: 0.8938 - val_loss: 0.4937 - val_acc: 0.8275 - 9s/epoch - 462ms/step
# Epoch 44/100
# 20/20 - 9s - loss: 0.3461 - acc: 0.8788 - val_loss: 0.5542 - val_acc: 0.8112 - 9s/epoch - 463ms/step
# Epoch 45/100
# 20/20 - 9s - loss: 0.3363 - acc: 0.8863 - val_loss: 0.4966 - val_acc: 0.8363 - 9s/epoch - 463ms/step
# Epoch 46/100
# 20/20 - 9s - loss: 0.3430 - acc: 0.9038 - val_loss: 0.4747 - val_acc: 0.8612 - 9s/epoch - 461ms/step
# Epoch 47/100
# 20/20 - 9s - loss: 0.3557 - acc: 0.8850 - val_loss: 0.4897 - val_acc: 0.8525 - 9s/epoch - 463ms/step
# Epoch 48/100
# 20/20 - 9s - loss: 0.3455 - acc: 0.8938 - val_loss: 0.4864 - val_acc: 0.8462 - 9s/epoch - 463ms/step
# Epoch 49/100
# 20/20 - 9s - loss: 0.3235 - acc: 0.9038 - val_loss: 0.4522 - val_acc: 0.8612 - 9s/epoch - 462ms/step
# Epoch 50/100
# 20/20 - 9s - loss: 0.2882 - acc: 0.9038 - val_loss: 0.4640 - val_acc: 0.8487 - 9s/epoch - 463ms/step
# Epoch 51/100
# 20/20 - 9s - loss: 0.3120 - acc: 0.9013 - val_loss: 0.4833 - val_acc: 0.8475 - 9s/epoch - 463ms/step
# Epoch 52/100
# 20/20 - 9s - loss: 0.3314 - acc: 0.9025 - val_loss: 0.4790 - val_acc: 0.8587 - 9s/epoch - 462ms/step
# Epoch 53/100
# 20/20 - 9s - loss: 0.2963 - acc: 0.9062 - val_loss: 0.4876 - val_acc: 0.8438 - 9s/epoch - 462ms/step
# Epoch 54/100
# 20/20 - 9s - loss: 0.2487 - acc: 0.9275 - val_loss: 0.4087 - val_acc: 0.8700 - 9s/epoch - 464ms/step
# Epoch 55/100
# 20/20 - 9s - loss: 0.2635 - acc: 0.9237 - val_loss: 0.4094 - val_acc: 0.8813 - 9s/epoch - 464ms/step
# Epoch 56/100
# 20/20 - 9s - loss: 0.2625 - acc: 0.9087 - val_loss: 0.4133 - val_acc: 0.8625 - 9s/epoch - 465ms/step
# Epoch 57/100
# 20/20 - 9s - loss: 0.2677 - acc: 0.9137 - val_loss: 0.4202 - val_acc: 0.8650 - 9s/epoch - 466ms/step
# Epoch 58/100
# 20/20 - 9s - loss: 0.2330 - acc: 0.9237 - val_loss: 0.4623 - val_acc: 0.8525 - 9s/epoch - 464ms/step
# Epoch 59/100
# 20/20 - 9s - loss: 0.2614 - acc: 0.9237 - val_loss: 0.4424 - val_acc: 0.8650 - 9s/epoch - 465ms/step
# Epoch 60/100
# 20/20 - 9s - loss: 0.2794 - acc: 0.9225 - val_loss: 0.3953 - val_acc: 0.8900 - 9s/epoch - 462ms/step
# Epoch 61/100
# 20/20 - 9s - loss: 0.2302 - acc: 0.9250 - val_loss: 0.4181 - val_acc: 0.8587 - 9s/epoch - 463ms/step
# Epoch 62/100
# 20/20 - 9s - loss: 0.2564 - acc: 0.9225 - val_loss: 0.4269 - val_acc: 0.8712 - 9s/epoch - 463ms/step
# Epoch 63/100
# 20/20 - 9s - loss: 0.2347 - acc: 0.9339 - val_loss: 0.4612 - val_acc: 0.8475 - 9s/epoch - 450ms/step
# Epoch 64/100
# 20/20 - 9s - loss: 0.2673 - acc: 0.9225 - val_loss: 0.4458 - val_acc: 0.8775 - 9s/epoch - 462ms/step
# Epoch 65/100
# 20/20 - 9s - loss: 0.2178 - acc: 0.9362 - val_loss: 0.4048 - val_acc: 0.8788 - 9s/epoch - 465ms/step
# Epoch 66/100
# 20/20 - 9s - loss: 0.2296 - acc: 0.9337 - val_loss: 0.3930 - val_acc: 0.8813 - 9s/epoch - 464ms/step
# Epoch 67/100
#
# Reached 95% accuracy so cancelling training!
# 20/20 - 9s - loss: 0.1801 - acc: 0.9538 - val_loss: 0.4465 - val_acc: 0.8562 - 9s/epoch - 464ms/step

# %%
# summarize history for accuracy and loss
plt.figure(figsize=(6, 4))
plt.plot(history.history['acc'], "g--", label="Accuracy of training data")
plt.plot(history.history['val_acc'], "g", label="Accuracy of validation data")
plt.plot(history.history['loss'], "r--", label="Loss of training data")
plt.plot(history.history['val_loss'], "r", label="Loss of validation data")
plt.title('Model Accuracy and Loss')
plt.ylabel('Accuracy and Loss')
plt.xlabel('Training Epoch')
plt.ylim(0)
plt.legend()
plt.show()

# %%
score = model.evaluate(test_generator, verbose=1)
print("\nAccuracy on test data: %0.2f" % score[1])
print("\nLoss on test data: %0.2f" % score[0])
# Out:
# 81/81 [==============================] - 9s 106ms/step - loss: 0.4372 - acc: 0.8678
#
# Accuracy on test data: 0.87
#
# Loss on test data: 0.44

# %%
LABELS = [0, 1, 2, 3, 4, 5, 6, 7]
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(matrix,
                cmap="coolwarm",
                linecolor='white',
                linewidths=1,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.show()

# %%
y_pred_test = model.predict(test_generator)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = test_generator.classes

show_confusion_matrix(max_y_test, max_y_pred_test)

print("\n--- Classification report for test data ---\n")

print(classification_report(max_y_test, max_y_pred_test))
# Out:
# 81/81 [==============================] - 9s 103ms/step
# --- Classification report for test data ---
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       658
#            1       0.92      0.87      0.90       641
#            2       0.85      0.90      0.87       563
#            3       0.84      0.86      0.85       251
#            4       0.84      0.78      0.81       243
#            5       0.84      0.75      0.79       220
#            6       0.78      0.67      0.72       219
#            7       0.97      0.96      0.97       421
#
#     accuracy                           0.87      3216
#    macro avg       0.86      0.84      0.85      3216
# weighted avg       0.87      0.87      0.87      3216

# %%
model.save("best_model_face_inception.h5")
